# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 9.6) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your interests.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])

print(X_train_feats.shape)
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# (49000, 155)

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM

learning_rates = [1e-8, 8e-7]
regularization_strengths = [5e3, 1e6]
num_iters = [1000,5000]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################


def acc_eval(X_train, y_train, X_val, y_val, model, verbose=False):
    y_train_pred = model.predict(X_train)
    acc_train = np.mean(y_train == y_train_pred)
    y_val_pred = model.predict(X_val)
    acc_val = np.mean(y_val == y_val_pred)
    if verbose:
        print('training accuracy: %f, validation accuracy: %f' % (acc_train, acc_val ))
    return acc_train, acc_val

def generatemesh(intervals_list, nxs_list, splitx_list):
    #inter_x1, inter_x2, inter_x3, inter_x4, nx1, nx2, nx3, nx4, splitx1='line', splitx2='line', splitx3 ='line', splitx4='line'):
    # x represents learning_rate, y represents regularization strength
    #assert len(intervals_list) == len(nxs_list) == len(splitx_list) 'number of parameters are not equal'
    
    axis_list = []
    for i,inter in enumerate(intervals_list):
        if splitx_list[i] == 'line':
            locals()['x' + str(int(i))] = np.linspace(inter[0], inter[1], num=nxs_list[i])
        elif splitx_list[i] == 'log':
            locals()['x' + str(int(i))] = np.logspace(np.log10(inter[0]), np.log10(inter[1]), num=nxs_list[i])
        else:
            assert splitx_list[i] == 'line' or 'log' 'split mode should be "line" or "log"'
        axis_list.append(locals()['x' + str(int(i))])
    
    grids_list = np.meshgrid(*axis_list)
    for i, grid in enumerate(grids_list):
        grids_list[i] = grids_list[i].ravel()
    points = list(zip(*grids_list))
    return points

intervals_list = [learning_rates, regularization_strengths, num_iters]; nxs_list = [6,5,6]; splitx_list=['log', 'log', 'log']
points = generatemesh(intervals_list, nxs_list, splitx_list)

print('Roughly search')
best_lr = 0; best_reg=0; best_ni = 0
for i,xy in enumerate(points):
    model = LinearSVM()
    lr = xy[0]; reg = xy[1]; ni = int(xy[2])
    print('No.%d parameter combination' %(int(i)+1))
    print('learning rate = %2.2e, regularization strength = %2.2e, num_iters = %d' %(lr, reg, ni))
    model.train(X_train_feats, y_train, learning_rate=lr, reg=reg, num_iters=ni)
    acc_train, acc_val = acc_eval(X_train_feats, y_train, X_val_feats, y_val, model, verbose=True)
    results[(lr,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_svm = model
        best_lr = lr; best_reg = reg; best_ni = ni

learning_rates = [best_lr*0.8, best_lr*1.2] 
regularization_strengths = [best_reg*0.8, best_reg*1.2]        
num_iters = [int(best_ni*0.8), int(best_ni*1.2)]  

intervals_list = [learning_rates, regularization_strengths, num_iters]; nxs_list = [4,4,4]; splitx_list=['log', 'log', 'log']
points = generatemesh(intervals_list, nxs_list, splitx_list)

print('Carefully search')
for i,xy in enumerate(points):
    model = LinearSVM()
    lr = xy[0]; reg = xy[1]; ni = int(xy[2])
    print('No.%d parameter combination' %(int(i)+1))
    print('learning rate = %2.2e, regularization strength = %2.2e, num_iters = %d' %(lr, reg, ni))
    model.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                      num_iters=ni)
    acc_train, acc_val = acc_eval(X_train_feats, y_train, X_val_feats, y_val, model, verbose=True)
    results[(lr,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_svm = model

# def 
# num_color_bins = 10 # Number of bins in the color histogram
# feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
# X_train_feats = extract_features(X_train, feature_fns, verbose=True)
# X_val_feats = extract_features(X_val, feature_fns)
# X_test_feats = extract_features(X_test, feature_fns)

# # Preprocessing: Subtract the mean feature
# mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
# X_train_feats -= mean_feat
# X_val_feats -= mean_feat
# X_test_feats -= mean_feat

# # Preprocessing: Divide by standard deviation. This ensures that each feature
# # has roughly the same scale.
# std_feat = np.std(X_train_feats, axis=0, keepdims=True)
# X_train_feats /= std_feat
# X_val_feats /= std_feat
# X_test_feats /= std_feat

# # Preprocessing: Add a bias dimension
# X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
# X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
# X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
        
################################################################################
#                              END OF YOUR CODE                                #
################################################################################

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Roughly search
# No.1 parameter combination
# learning rate = 1.00e-08, regularization strength = 5.00e+03, num_iters = 1000
# training accuracy: 0.129592, validation accuracy: 0.138000
# No.2 parameter combination
# learning rate = 1.00e-08, regularization strength = 5.00e+03, num_iters = 1379
# training accuracy: 0.131122, validation accuracy: 0.144000
# No.3 parameter combination
# learning rate = 1.00e-08, regularization strength = 5.00e+03, num_iters = 1903
# training accuracy: 0.099918, validation accuracy: 0.086000
# No.4 parameter combination
# learning rate = 1.00e-08, regularization strength = 5.00e+03, num_iters = 2626
# training accuracy: 0.125122, validation accuracy: 0.110000
# No.5 parameter combination
# learning rate = 1.00e-08, regularization strength = 5.00e+03, num_iters = 3623
# training accuracy: 0.107408, validation accuracy: 0.099000
# No.6 parameter combination
# learning rate = 1.00e-08, regularization strength = 5.00e+03, num_iters = 4999
# training accuracy: 0.091959, validation accuracy: 0.085000
# No.7 parameter combination
# learning rate = 2.40e-08, regularization strength = 5.00e+03, num_iters = 1000
# training accuracy: 0.092469, validation accuracy: 0.087000
# No.8 parameter combination
# learning rate = 2.40e-08, regularization strength = 5.00e+03, num_iters = 1379
# training accuracy: 0.091551, validation accuracy: 0.098000
# No.9 parameter combination
# learning rate = 2.40e-08, regularization strength = 5.00e+03, num_iters = 1903
# training accuracy: 0.097224, validation accuracy: 0.101000
# No.10 parameter combination
# learning rate = 2.40e-08, regularization strength = 5.00e+03, num_iters = 2626
# training accuracy: 0.112816, validation accuracy: 0.115000
# No.11 parameter combination
# learning rate = 2.40e-08, regularization strength = 5.00e+03, num_iters = 3623
# training accuracy: 0.110122, validation accuracy: 0.110000
# No.12 parameter combination
# learning rate = 2.40e-08, regularization strength = 5.00e+03, num_iters = 4999
# training accuracy: 0.127286, validation accuracy: 0.112000
# No.13 parameter combination
# learning rate = 5.77e-08, regularization strength = 5.00e+03, num_iters = 1000
# training accuracy: 0.118551, validation accuracy: 0.124000
# No.14 parameter combination
# learning rate = 5.77e-08, regularization strength = 5.00e+03, num_iters = 1379
# training accuracy: 0.100388, validation accuracy: 0.118000
# No.15 parameter combination
# learning rate = 5.77e-08, regularization strength = 5.00e+03, num_iters = 1903
# training accuracy: 0.110020, validation accuracy: 0.121000
# No.16 parameter combination
# learning rate = 5.77e-08, regularization strength = 5.00e+03, num_iters = 2626
# training accuracy: 0.139163, validation accuracy: 0.158000
# No.17 parameter combination
# learning rate = 5.77e-08, regularization strength = 5.00e+03, num_iters = 3623
# training accuracy: 0.169898, validation accuracy: 0.160000
# No.18 parameter combination
# learning rate = 5.77e-08, regularization strength = 5.00e+03, num_iters = 4999
# training accuracy: 0.256653, validation accuracy: 0.247000
# No.19 parameter combination
# learning rate = 1.39e-07, regularization strength = 5.00e+03, num_iters = 1000
# training accuracy: 0.162245, validation accuracy: 0.152000
# No.20 parameter combination
# learning rate = 1.39e-07, regularization strength = 5.00e+03, num_iters = 1379
# training accuracy: 0.172633, validation accuracy: 0.162000
# No.21 parameter combination
# learning rate = 1.39e-07, regularization strength = 5.00e+03, num_iters = 1903
# training accuracy: 0.246184, validation accuracy: 0.239000
# No.22 parameter combination
# learning rate = 1.39e-07, regularization strength = 5.00e+03, num_iters = 2626
# training accuracy: 0.350653, validation accuracy: 0.340000
# No.23 parameter combination
# learning rate = 1.39e-07, regularization strength = 5.00e+03, num_iters = 3623
# training accuracy: 0.411776, validation accuracy: 0.413000
# No.24 parameter combination
# learning rate = 1.39e-07, regularization strength = 5.00e+03, num_iters = 4999
# training accuracy: 0.414020, validation accuracy: 0.415000
# No.25 parameter combination
# learning rate = 3.33e-07, regularization strength = 5.00e+03, num_iters = 1000
# training accuracy: 0.303878, validation accuracy: 0.276000
# No.26 parameter combination
# learning rate = 3.33e-07, regularization strength = 5.00e+03, num_iters = 1379
# training accuracy: 0.399143, validation accuracy: 0.403000
# No.27 parameter combination
# learning rate = 3.33e-07, regularization strength = 5.00e+03, num_iters = 1903
# training accuracy: 0.415143, validation accuracy: 0.419000
# No.28 parameter combination
# learning rate = 3.33e-07, regularization strength = 5.00e+03, num_iters = 2626
# training accuracy: 0.415245, validation accuracy: 0.414000
# No.29 parameter combination
# learning rate = 3.33e-07, regularization strength = 5.00e+03, num_iters = 3623
# training accuracy: 0.416367, validation accuracy: 0.419000
# No.30 parameter combination
# learning rate = 3.33e-07, regularization strength = 5.00e+03, num_iters = 4999
# training accuracy: 0.413571, validation accuracy: 0.412000
# No.31 parameter combination
# learning rate = 8.00e-07, regularization strength = 5.00e+03, num_iters = 1000
# training accuracy: 0.413551, validation accuracy: 0.405000
# No.32 parameter combination
# learning rate = 8.00e-07, regularization strength = 5.00e+03, num_iters = 1379
# training accuracy: 0.414306, validation accuracy: 0.422000
# No.33 parameter combination
# learning rate = 8.00e-07, regularization strength = 5.00e+03, num_iters = 1903
# training accuracy: 0.413286, validation accuracy: 0.418000
# No.34 parameter combination
# learning rate = 8.00e-07, regularization strength = 5.00e+03, num_iters = 2626
# training accuracy: 0.415735, validation accuracy: 0.414000
# No.35 parameter combination
# learning rate = 8.00e-07, regularization strength = 5.00e+03, num_iters = 3623
# training accuracy: 0.413694, validation accuracy: 0.413000
# No.36 parameter combination
# learning rate = 8.00e-07, regularization strength = 5.00e+03, num_iters = 4999
# training accuracy: 0.414306, validation accuracy: 0.417000
# No.37 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.88e+04, num_iters = 1000
# training accuracy: 0.103980, validation accuracy: 0.094000
# No.38 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.88e+04, num_iters = 1379
# training accuracy: 0.077898, validation accuracy: 0.083000
# No.39 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.88e+04, num_iters = 1903
# training accuracy: 0.087837, validation accuracy: 0.081000
# No.40 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.88e+04, num_iters = 2626
# training accuracy: 0.104755, validation accuracy: 0.097000
# No.41 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.88e+04, num_iters = 3623
# training accuracy: 0.103755, validation accuracy: 0.116000
# No.42 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.88e+04, num_iters = 4999
# training accuracy: 0.098367, validation accuracy: 0.117000
# No.43 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.88e+04, num_iters = 1000
# training accuracy: 0.122449, validation accuracy: 0.133000
# No.44 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.88e+04, num_iters = 1379
# training accuracy: 0.128204, validation accuracy: 0.118000
# No.45 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.88e+04, num_iters = 1903
# training accuracy: 0.136857, validation accuracy: 0.135000
# No.46 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.88e+04, num_iters = 2626
# training accuracy: 0.145000, validation accuracy: 0.145000
# No.47 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.88e+04, num_iters = 3623
# training accuracy: 0.177531, validation accuracy: 0.167000
# No.48 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.88e+04, num_iters = 4999
# training accuracy: 0.310918, validation accuracy: 0.326000
# No.49 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.88e+04, num_iters = 1000
# training accuracy: 0.116327, validation accuracy: 0.121000
# No.50 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.88e+04, num_iters = 1379
# training accuracy: 0.164367, validation accuracy: 0.181000
# No.51 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.88e+04, num_iters = 1903
# training accuracy: 0.256510, validation accuracy: 0.254000
# No.52 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.88e+04, num_iters = 2626
# training accuracy: 0.388449, validation accuracy: 0.384000
# No.53 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.88e+04, num_iters = 3623
# training accuracy: 0.415245, validation accuracy: 0.419000
# No.54 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.88e+04, num_iters = 4999
# training accuracy: 0.415571, validation accuracy: 0.416000
# No.55 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.88e+04, num_iters = 1000
# training accuracy: 0.370571, validation accuracy: 0.368000
# No.56 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.88e+04, num_iters = 1379
# training accuracy: 0.411837, validation accuracy: 0.423000
# No.57 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.88e+04, num_iters = 1903
# training accuracy: 0.418000, validation accuracy: 0.422000
# No.58 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.88e+04, num_iters = 2626
# training accuracy: 0.413653, validation accuracy: 0.416000
# No.59 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.88e+04, num_iters = 3623
# training accuracy: 0.414980, validation accuracy: 0.412000
# No.60 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.88e+04, num_iters = 4999
# training accuracy: 0.414408, validation accuracy: 0.417000
# No.61 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.88e+04, num_iters = 1000
# training accuracy: 0.412571, validation accuracy: 0.428000
# No.62 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.88e+04, num_iters = 1379
# training accuracy: 0.415224, validation accuracy: 0.427000
# No.63 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.88e+04, num_iters = 1903
# training accuracy: 0.412122, validation accuracy: 0.417000
# No.64 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.88e+04, num_iters = 2626
# training accuracy: 0.414367, validation accuracy: 0.419000
# No.65 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.88e+04, num_iters = 3623
# training accuracy: 0.413980, validation accuracy: 0.417000
# No.66 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.88e+04, num_iters = 4999
# training accuracy: 0.410388, validation accuracy: 0.411000
# No.67 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.88e+04, num_iters = 1000
# training accuracy: 0.413041, validation accuracy: 0.417000
# No.68 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.88e+04, num_iters = 1379
# training accuracy: 0.411020, validation accuracy: 0.409000
# No.69 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.88e+04, num_iters = 1903
# training accuracy: 0.405653, validation accuracy: 0.401000
# No.70 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.88e+04, num_iters = 2626
# training accuracy: 0.410980, validation accuracy: 0.402000
# No.71 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.88e+04, num_iters = 3623
# training accuracy: 0.412857, validation accuracy: 0.415000
# No.72 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.88e+04, num_iters = 4999
# training accuracy: 0.416755, validation accuracy: 0.420000
# No.73 parameter combination
# learning rate = 1.00e-08, regularization strength = 7.07e+04, num_iters = 1000
# training accuracy: 0.114551, validation accuracy: 0.117000
# No.74 parameter combination
# learning rate = 1.00e-08, regularization strength = 7.07e+04, num_iters = 1379
# training accuracy: 0.094082, validation accuracy: 0.093000
# No.75 parameter combination
# learning rate = 1.00e-08, regularization strength = 7.07e+04, num_iters = 1903
# training accuracy: 0.114347, validation accuracy: 0.114000
# No.76 parameter combination
# learning rate = 1.00e-08, regularization strength = 7.07e+04, num_iters = 2626
# training accuracy: 0.129061, validation accuracy: 0.133000
# No.77 parameter combination
# learning rate = 1.00e-08, regularization strength = 7.07e+04, num_iters = 3623
# training accuracy: 0.244020, validation accuracy: 0.241000
# No.78 parameter combination
# learning rate = 1.00e-08, regularization strength = 7.07e+04, num_iters = 4999
# training accuracy: 0.389184, validation accuracy: 0.381000
# No.79 parameter combination
# learning rate = 2.40e-08, regularization strength = 7.07e+04, num_iters = 1000
# training accuracy: 0.127755, validation accuracy: 0.114000
# No.80 parameter combination
# learning rate = 2.40e-08, regularization strength = 7.07e+04, num_iters = 1379
# training accuracy: 0.195735, validation accuracy: 0.183000
# No.81 parameter combination
# learning rate = 2.40e-08, regularization strength = 7.07e+04, num_iters = 1903
# training accuracy: 0.376673, validation accuracy: 0.398000
# No.82 parameter combination
# learning rate = 2.40e-08, regularization strength = 7.07e+04, num_iters = 2626
# training accuracy: 0.412796, validation accuracy: 0.418000
# No.83 parameter combination
# learning rate = 2.40e-08, regularization strength = 7.07e+04, num_iters = 3623
# training accuracy: 0.413041, validation accuracy: 0.419000
# No.84 parameter combination
# learning rate = 2.40e-08, regularization strength = 7.07e+04, num_iters = 4999
# training accuracy: 0.416980, validation accuracy: 0.423000
# No.85 parameter combination
# learning rate = 5.77e-08, regularization strength = 7.07e+04, num_iters = 1000
# training accuracy: 0.409633, validation accuracy: 0.417000
# No.86 parameter combination
# learning rate = 5.77e-08, regularization strength = 7.07e+04, num_iters = 1379
# training accuracy: 0.418408, validation accuracy: 0.419000
# No.87 parameter combination
# learning rate = 5.77e-08, regularization strength = 7.07e+04, num_iters = 1903
# training accuracy: 0.416429, validation accuracy: 0.414000
# No.88 parameter combination
# learning rate = 5.77e-08, regularization strength = 7.07e+04, num_iters = 2626
# training accuracy: 0.415204, validation accuracy: 0.416000
# No.89 parameter combination
# learning rate = 5.77e-08, regularization strength = 7.07e+04, num_iters = 3623
# training accuracy: 0.415265, validation accuracy: 0.418000
# No.90 parameter combination
# learning rate = 5.77e-08, regularization strength = 7.07e+04, num_iters = 4999
# training accuracy: 0.413122, validation accuracy: 0.416000
# No.91 parameter combination
# learning rate = 1.39e-07, regularization strength = 7.07e+04, num_iters = 1000
# training accuracy: 0.414776, validation accuracy: 0.407000
# No.92 parameter combination
# learning rate = 1.39e-07, regularization strength = 7.07e+04, num_iters = 1379
# training accuracy: 0.414571, validation accuracy: 0.407000
# No.93 parameter combination
# learning rate = 1.39e-07, regularization strength = 7.07e+04, num_iters = 1903
# training accuracy: 0.407735, validation accuracy: 0.402000
# No.94 parameter combination
# learning rate = 1.39e-07, regularization strength = 7.07e+04, num_iters = 2626
# training accuracy: 0.415306, validation accuracy: 0.419000
# No.95 parameter combination
# learning rate = 1.39e-07, regularization strength = 7.07e+04, num_iters = 3623
# training accuracy: 0.420020, validation accuracy: 0.422000
# No.96 parameter combination
# learning rate = 1.39e-07, regularization strength = 7.07e+04, num_iters = 4999
# training accuracy: 0.415143, validation accuracy: 0.410000
# No.97 parameter combination
# learning rate = 3.33e-07, regularization strength = 7.07e+04, num_iters = 1000
# training accuracy: 0.409082, validation accuracy: 0.401000
# No.98 parameter combination
# learning rate = 3.33e-07, regularization strength = 7.07e+04, num_iters = 1379
# training accuracy: 0.416408, validation accuracy: 0.416000
# No.99 parameter combination
# learning rate = 3.33e-07, regularization strength = 7.07e+04, num_iters = 1903
# training accuracy: 0.414082, validation accuracy: 0.410000
# No.100 parameter combination
# learning rate = 3.33e-07, regularization strength = 7.07e+04, num_iters = 2626
# training accuracy: 0.417490, validation accuracy: 0.429000
# No.101 parameter combination
# learning rate = 3.33e-07, regularization strength = 7.07e+04, num_iters = 3623
# training accuracy: 0.406122, validation accuracy: 0.416000
# No.102 parameter combination
# learning rate = 3.33e-07, regularization strength = 7.07e+04, num_iters = 4999
# training accuracy: 0.415449, validation accuracy: 0.416000
# No.103 parameter combination
# learning rate = 8.00e-07, regularization strength = 7.07e+04, num_iters = 1000
# training accuracy: 0.409082, validation accuracy: 0.411000
# No.104 parameter combination
# learning rate = 8.00e-07, regularization strength = 7.07e+04, num_iters = 1379
# training accuracy: 0.402531, validation accuracy: 0.389000
# No.105 parameter combination
# learning rate = 8.00e-07, regularization strength = 7.07e+04, num_iters = 1903
# training accuracy: 0.405367, validation accuracy: 0.413000
# No.106 parameter combination
# learning rate = 8.00e-07, regularization strength = 7.07e+04, num_iters = 2626
# training accuracy: 0.395245, validation accuracy: 0.390000
# No.107 parameter combination
# learning rate = 8.00e-07, regularization strength = 7.07e+04, num_iters = 3623
# training accuracy: 0.409857, validation accuracy: 0.415000
# No.108 parameter combination
# learning rate = 8.00e-07, regularization strength = 7.07e+04, num_iters = 4999
# training accuracy: 0.405837, validation accuracy: 0.419000
# No.109 parameter combination
# learning rate = 1.00e-08, regularization strength = 2.66e+05, num_iters = 1000
# training accuracy: 0.166102, validation accuracy: 0.148000
# No.110 parameter combination
# learning rate = 1.00e-08, regularization strength = 2.66e+05, num_iters = 1379
# training accuracy: 0.327592, validation accuracy: 0.327000
# No.111 parameter combination
# learning rate = 1.00e-08, regularization strength = 2.66e+05, num_iters = 1903
# training accuracy: 0.414327, validation accuracy: 0.416000
# No.112 parameter combination
# learning rate = 1.00e-08, regularization strength = 2.66e+05, num_iters = 2626
# training accuracy: 0.415694, validation accuracy: 0.418000
# No.113 parameter combination
# learning rate = 1.00e-08, regularization strength = 2.66e+05, num_iters = 3623
# training accuracy: 0.412041, validation accuracy: 0.410000
# No.114 parameter combination
# learning rate = 1.00e-08, regularization strength = 2.66e+05, num_iters = 4999
# training accuracy: 0.412633, validation accuracy: 0.412000
# No.115 parameter combination
# learning rate = 2.40e-08, regularization strength = 2.66e+05, num_iters = 1000
# training accuracy: 0.414286, validation accuracy: 0.419000
# No.116 parameter combination
# learning rate = 2.40e-08, regularization strength = 2.66e+05, num_iters = 1379
# training accuracy: 0.414612, validation accuracy: 0.416000
# No.117 parameter combination
# learning rate = 2.40e-08, regularization strength = 2.66e+05, num_iters = 1903
# training accuracy: 0.417388, validation accuracy: 0.417000
# No.118 parameter combination
# learning rate = 2.40e-08, regularization strength = 2.66e+05, num_iters = 2626
# training accuracy: 0.412816, validation accuracy: 0.419000
# No.119 parameter combination
# learning rate = 2.40e-08, regularization strength = 2.66e+05, num_iters = 3623
# training accuracy: 0.412673, validation accuracy: 0.414000
# No.120 parameter combination
# learning rate = 2.40e-08, regularization strength = 2.66e+05, num_iters = 4999
# training accuracy: 0.412531, validation accuracy: 0.402000
# No.121 parameter combination
# learning rate = 5.77e-08, regularization strength = 2.66e+05, num_iters = 1000
# training accuracy: 0.415286, validation accuracy: 0.407000
# No.122 parameter combination
# learning rate = 5.77e-08, regularization strength = 2.66e+05, num_iters = 1379
# training accuracy: 0.407041, validation accuracy: 0.391000
# No.123 parameter combination
# learning rate = 5.77e-08, regularization strength = 2.66e+05, num_iters = 1903
# training accuracy: 0.412694, validation accuracy: 0.409000
# No.124 parameter combination
# learning rate = 5.77e-08, regularization strength = 2.66e+05, num_iters = 2626
# training accuracy: 0.412612, validation accuracy: 0.416000
# No.125 parameter combination
# learning rate = 5.77e-08, regularization strength = 2.66e+05, num_iters = 3623
# training accuracy: 0.412204, validation accuracy: 0.421000
# No.126 parameter combination
# learning rate = 5.77e-08, regularization strength = 2.66e+05, num_iters = 4999
# training accuracy: 0.411571, validation accuracy: 0.403000
# No.127 parameter combination
# learning rate = 1.39e-07, regularization strength = 2.66e+05, num_iters = 1000
# training accuracy: 0.410408, validation accuracy: 0.416000
# No.128 parameter combination
# learning rate = 1.39e-07, regularization strength = 2.66e+05, num_iters = 1379
# training accuracy: 0.407531, validation accuracy: 0.407000
# No.129 parameter combination
# learning rate = 1.39e-07, regularization strength = 2.66e+05, num_iters = 1903
# training accuracy: 0.411367, validation accuracy: 0.426000
# No.130 parameter combination
# learning rate = 1.39e-07, regularization strength = 2.66e+05, num_iters = 2626
# training accuracy: 0.396959, validation accuracy: 0.380000
# No.131 parameter combination
# learning rate = 1.39e-07, regularization strength = 2.66e+05, num_iters = 3623
# training accuracy: 0.413020, validation accuracy: 0.430000
# No.132 parameter combination
# learning rate = 1.39e-07, regularization strength = 2.66e+05, num_iters = 4999
# training accuracy: 0.413041, validation accuracy: 0.407000
# No.133 parameter combination
# learning rate = 3.33e-07, regularization strength = 2.66e+05, num_iters = 1000
# training accuracy: 0.406000, validation accuracy: 0.416000
# No.134 parameter combination
# learning rate = 3.33e-07, regularization strength = 2.66e+05, num_iters = 1379
# training accuracy: 0.387673, validation accuracy: 0.396000
# No.135 parameter combination
# learning rate = 3.33e-07, regularization strength = 2.66e+05, num_iters = 1903
# training accuracy: 0.408020, validation accuracy: 0.419000
# No.136 parameter combination
# learning rate = 3.33e-07, regularization strength = 2.66e+05, num_iters = 2626
# training accuracy: 0.397939, validation accuracy: 0.383000
# No.137 parameter combination
# learning rate = 3.33e-07, regularization strength = 2.66e+05, num_iters = 3623
# training accuracy: 0.397347, validation accuracy: 0.381000
# No.138 parameter combination
# learning rate = 3.33e-07, regularization strength = 2.66e+05, num_iters = 4999
# training accuracy: 0.391000, validation accuracy: 0.365000
# No.139 parameter combination
# learning rate = 8.00e-07, regularization strength = 2.66e+05, num_iters = 1000
# training accuracy: 0.378735, validation accuracy: 0.370000
# No.140 parameter combination
# learning rate = 8.00e-07, regularization strength = 2.66e+05, num_iters = 1379
# training accuracy: 0.372429, validation accuracy: 0.354000
# No.141 parameter combination
# learning rate = 8.00e-07, regularization strength = 2.66e+05, num_iters = 1903
# training accuracy: 0.382633, validation accuracy: 0.386000
# No.142 parameter combination
# learning rate = 8.00e-07, regularization strength = 2.66e+05, num_iters = 2626
# training accuracy: 0.364327, validation accuracy: 0.356000
# No.143 parameter combination
# learning rate = 8.00e-07, regularization strength = 2.66e+05, num_iters = 3623
# training accuracy: 0.396918, validation accuracy: 0.380000
# No.144 parameter combination
# learning rate = 8.00e-07, regularization strength = 2.66e+05, num_iters = 4999
# training accuracy: 0.389327, validation accuracy: 0.387000
# No.145 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.00e+06, num_iters = 1000
# training accuracy: 0.418184, validation accuracy: 0.425000
# No.146 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.00e+06, num_iters = 1379
# training accuracy: 0.406469, validation accuracy: 0.399000
# No.147 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.00e+06, num_iters = 1903
# training accuracy: 0.412816, validation accuracy: 0.417000
# No.148 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.00e+06, num_iters = 2626
# training accuracy: 0.413551, validation accuracy: 0.416000
# No.149 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.00e+06, num_iters = 3623
# training accuracy: 0.414286, validation accuracy: 0.412000
# No.150 parameter combination
# learning rate = 1.00e-08, regularization strength = 1.00e+06, num_iters = 4999
# training accuracy: 0.415082, validation accuracy: 0.421000
# No.151 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.00e+06, num_iters = 1000
# training accuracy: 0.415082, validation accuracy: 0.411000
# No.152 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.00e+06, num_iters = 1379
# training accuracy: 0.416286, validation accuracy: 0.425000
# No.153 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.00e+06, num_iters = 1903
# training accuracy: 0.414755, validation accuracy: 0.416000
# No.154 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.00e+06, num_iters = 2626
# training accuracy: 0.409429, validation accuracy: 0.423000
# No.155 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.00e+06, num_iters = 3623
# training accuracy: 0.416408, validation accuracy: 0.404000
# No.156 parameter combination
# learning rate = 2.40e-08, regularization strength = 1.00e+06, num_iters = 4999
# training accuracy: 0.418061, validation accuracy: 0.427000
# No.157 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.00e+06, num_iters = 1000
# training accuracy: 0.416796, validation accuracy: 0.435000
# No.158 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.00e+06, num_iters = 1379
# training accuracy: 0.411531, validation accuracy: 0.411000
# No.159 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.00e+06, num_iters = 1903
# training accuracy: 0.406388, validation accuracy: 0.411000
# No.160 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.00e+06, num_iters = 2626
# training accuracy: 0.398327, validation accuracy: 0.404000
# No.161 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.00e+06, num_iters = 3623
# training accuracy: 0.403531, validation accuracy: 0.394000
# No.162 parameter combination
# learning rate = 5.77e-08, regularization strength = 1.00e+06, num_iters = 4999
# training accuracy: 0.385980, validation accuracy: 0.409000
# No.163 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.00e+06, num_iters = 1000
# training accuracy: 0.386735, validation accuracy: 0.371000
# No.164 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.00e+06, num_iters = 1379
# training accuracy: 0.396612, validation accuracy: 0.392000
# No.165 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.00e+06, num_iters = 1903
# training accuracy: 0.400408, validation accuracy: 0.382000
# No.166 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.00e+06, num_iters = 2626
# training accuracy: 0.384020, validation accuracy: 0.393000
# No.167 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.00e+06, num_iters = 3623
# training accuracy: 0.391204, validation accuracy: 0.384000
# No.168 parameter combination
# learning rate = 1.39e-07, regularization strength = 1.00e+06, num_iters = 4999
# training accuracy: 0.382224, validation accuracy: 0.393000
# No.169 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.00e+06, num_iters = 1000
# training accuracy: 0.354347, validation accuracy: 0.335000
# No.170 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.00e+06, num_iters = 1379
# training accuracy: 0.322653, validation accuracy: 0.327000
# No.171 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.00e+06, num_iters = 1903
# training accuracy: 0.353776, validation accuracy: 0.348000
# No.172 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.00e+06, num_iters = 2626
# training accuracy: 0.366510, validation accuracy: 0.340000
# No.173 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.00e+06, num_iters = 3623
# training accuracy: 0.343633, validation accuracy: 0.322000
# No.174 parameter combination
# learning rate = 3.33e-07, regularization strength = 1.00e+06, num_iters = 4999
# training accuracy: 0.365959, validation accuracy: 0.371000
# No.175 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.00e+06, num_iters = 1000
# training accuracy: 0.237653, validation accuracy: 0.250000
# No.176 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.00e+06, num_iters = 1379
# training accuracy: 0.281571, validation accuracy: 0.285000
# No.177 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.00e+06, num_iters = 1903
# training accuracy: 0.251143, validation accuracy: 0.250000
# No.178 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.00e+06, num_iters = 2626
# training accuracy: 0.253776, validation accuracy: 0.229000
# No.179 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.00e+06, num_iters = 3623
# training accuracy: 0.241184, validation accuracy: 0.207000
# No.180 parameter combination
# learning rate = 8.00e-07, regularization strength = 1.00e+06, num_iters = 4999
# training accuracy: 0.246633, validation accuracy: 0.212000
# Carefully search
# No.1 parameter combination
# learning rate = 4.62e-08, regularization strength = 8.00e+05, num_iters = 800
# training accuracy: 0.410918, validation accuracy: 0.413000
# No.2 parameter combination
# learning rate = 4.62e-08, regularization strength = 8.00e+05, num_iters = 915
# training accuracy: 0.403041, validation accuracy: 0.395000
# No.3 parameter combination
# learning rate = 4.62e-08, regularization strength = 8.00e+05, num_iters = 1048
# training accuracy: 0.403531, validation accuracy: 0.397000
# No.4 parameter combination
# learning rate = 4.62e-08, regularization strength = 8.00e+05, num_iters = 1199
# training accuracy: 0.405265, validation accuracy: 0.402000
# No.5 parameter combination
# learning rate = 5.28e-08, regularization strength = 8.00e+05, num_iters = 800
# training accuracy: 0.413837, validation accuracy: 0.405000
# No.6 parameter combination
# learning rate = 5.28e-08, regularization strength = 8.00e+05, num_iters = 915
# training accuracy: 0.412959, validation accuracy: 0.418000
# No.7 parameter combination
# learning rate = 5.28e-08, regularization strength = 8.00e+05, num_iters = 1048
# training accuracy: 0.403571, validation accuracy: 0.394000
# No.8 parameter combination
# learning rate = 5.28e-08, regularization strength = 8.00e+05, num_iters = 1199
# training accuracy: 0.417061, validation accuracy: 0.415000
# No.9 parameter combination
# learning rate = 6.05e-08, regularization strength = 8.00e+05, num_iters = 800
# training accuracy: 0.405939, validation accuracy: 0.407000
# No.10 parameter combination
# learning rate = 6.05e-08, regularization strength = 8.00e+05, num_iters = 915
# training accuracy: 0.399367, validation accuracy: 0.385000
# No.11 parameter combination
# learning rate = 6.05e-08, regularization strength = 8.00e+05, num_iters = 1048
# training accuracy: 0.404816, validation accuracy: 0.410000
# No.12 parameter combination
# learning rate = 6.05e-08, regularization strength = 8.00e+05, num_iters = 1199
# training accuracy: 0.397714, validation accuracy: 0.384000
# No.13 parameter combination
# learning rate = 6.92e-08, regularization strength = 8.00e+05, num_iters = 800
# training accuracy: 0.410510, validation accuracy: 0.413000
# No.14 parameter combination
# learning rate = 6.92e-08, regularization strength = 8.00e+05, num_iters = 915
# training accuracy: 0.405755, validation accuracy: 0.395000
# No.15 parameter combination
# learning rate = 6.92e-08, regularization strength = 8.00e+05, num_iters = 1048
# training accuracy: 0.409776, validation accuracy: 0.398000
# No.16 parameter combination
# learning rate = 6.92e-08, regularization strength = 8.00e+05, num_iters = 1199
# training accuracy: 0.392265, validation accuracy: 0.366000
# No.17 parameter combination
# learning rate = 4.62e-08, regularization strength = 9.16e+05, num_iters = 800
# training accuracy: 0.409816, validation accuracy: 0.417000
# No.18 parameter combination
# learning rate = 4.62e-08, regularization strength = 9.16e+05, num_iters = 915
# training accuracy: 0.403755, validation accuracy: 0.405000
# No.19 parameter combination
# learning rate = 4.62e-08, regularization strength = 9.16e+05, num_iters = 1048
# training accuracy: 0.403286, validation accuracy: 0.396000
# No.20 parameter combination
# learning rate = 4.62e-08, regularization strength = 9.16e+05, num_iters = 1199
# training accuracy: 0.408776, validation accuracy: 0.414000
# No.21 parameter combination
# learning rate = 5.28e-08, regularization strength = 9.16e+05, num_iters = 800
# training accuracy: 0.402898, validation accuracy: 0.408000
# No.22 parameter combination
# learning rate = 5.28e-08, regularization strength = 9.16e+05, num_iters = 915
# training accuracy: 0.399102, validation accuracy: 0.396000
# No.23 parameter combination
# learning rate = 5.28e-08, regularization strength = 9.16e+05, num_iters = 1048
# training accuracy: 0.400918, validation accuracy: 0.391000
# No.24 parameter combination
# learning rate = 5.28e-08, regularization strength = 9.16e+05, num_iters = 1199
# training accuracy: 0.411000, validation accuracy: 0.416000
# No.25 parameter combination
# learning rate = 6.05e-08, regularization strength = 9.16e+05, num_iters = 800
# training accuracy: 0.414571, validation accuracy: 0.419000
# No.26 parameter combination
# learning rate = 6.05e-08, regularization strength = 9.16e+05, num_iters = 915
# training accuracy: 0.416265, validation accuracy: 0.432000
# No.27 parameter combination
# learning rate = 6.05e-08, regularization strength = 9.16e+05, num_iters = 1048
# training accuracy: 0.391796, validation accuracy: 0.402000
# No.28 parameter combination
# learning rate = 6.05e-08, regularization strength = 9.16e+05, num_iters = 1199
# training accuracy: 0.409551, validation accuracy: 0.409000
# No.29 parameter combination
# learning rate = 6.92e-08, regularization strength = 9.16e+05, num_iters = 800
# training accuracy: 0.405878, validation accuracy: 0.412000
# No.30 parameter combination
# learning rate = 6.92e-08, regularization strength = 9.16e+05, num_iters = 915
# training accuracy: 0.393714, validation accuracy: 0.375000
# No.31 parameter combination
# learning rate = 6.92e-08, regularization strength = 9.16e+05, num_iters = 1048
# training accuracy: 0.411551, validation accuracy: 0.415000
# No.32 parameter combination
# learning rate = 6.92e-08, regularization strength = 9.16e+05, num_iters = 1199
# training accuracy: 0.399837, validation accuracy: 0.406000
# No.33 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.05e+06, num_iters = 800
# training accuracy: 0.408020, validation accuracy: 0.386000
# No.34 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.05e+06, num_iters = 915
# training accuracy: 0.417061, validation accuracy: 0.435000
# No.35 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.05e+06, num_iters = 1048
# training accuracy: 0.406469, validation accuracy: 0.403000
# No.36 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.05e+06, num_iters = 1199
# training accuracy: 0.412204, validation accuracy: 0.408000
# No.37 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.05e+06, num_iters = 800
# training accuracy: 0.405673, validation accuracy: 0.406000
# No.38 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.05e+06, num_iters = 915
# training accuracy: 0.407224, validation accuracy: 0.417000
# No.39 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.05e+06, num_iters = 1048
# training accuracy: 0.412694, validation accuracy: 0.402000
# No.40 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.05e+06, num_iters = 1199
# training accuracy: 0.408551, validation accuracy: 0.426000
# No.41 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.05e+06, num_iters = 800
# training accuracy: 0.402796, validation accuracy: 0.405000
# No.42 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.05e+06, num_iters = 915
# training accuracy: 0.402327, validation accuracy: 0.398000
# No.43 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.05e+06, num_iters = 1048
# training accuracy: 0.401918, validation accuracy: 0.402000
# No.44 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.05e+06, num_iters = 1199
# training accuracy: 0.403551, validation accuracy: 0.402000
# No.45 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.05e+06, num_iters = 800
# training accuracy: 0.387184, validation accuracy: 0.381000
# No.46 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.05e+06, num_iters = 915
# training accuracy: 0.400347, validation accuracy: 0.387000
# No.47 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.05e+06, num_iters = 1048
# training accuracy: 0.397633, validation accuracy: 0.404000
# No.48 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.05e+06, num_iters = 1199
# training accuracy: 0.400163, validation accuracy: 0.400000
# No.49 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.20e+06, num_iters = 800
# training accuracy: 0.411408, validation accuracy: 0.420000
# No.50 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.20e+06, num_iters = 915
# training accuracy: 0.395429, validation accuracy: 0.378000
# No.51 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.20e+06, num_iters = 1048
# training accuracy: 0.408367, validation accuracy: 0.411000
# No.52 parameter combination
# learning rate = 4.62e-08, regularization strength = 1.20e+06, num_iters = 1199
# training accuracy: 0.398306, validation accuracy: 0.389000
# No.53 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.20e+06, num_iters = 800
# training accuracy: 0.402408, validation accuracy: 0.397000
# No.54 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.20e+06, num_iters = 915
# training accuracy: 0.404898, validation accuracy: 0.421000
# No.55 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.20e+06, num_iters = 1048
# training accuracy: 0.396000, validation accuracy: 0.379000
# No.56 parameter combination
# learning rate = 5.28e-08, regularization strength = 1.20e+06, num_iters = 1199
# training accuracy: 0.394714, validation accuracy: 0.390000
# No.57 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.20e+06, num_iters = 800
# training accuracy: 0.404776, validation accuracy: 0.416000
# No.58 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.20e+06, num_iters = 915
# training accuracy: 0.404714, validation accuracy: 0.397000
# No.59 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.20e+06, num_iters = 1048
# training accuracy: 0.396755, validation accuracy: 0.387000
# No.60 parameter combination
# learning rate = 6.05e-08, regularization strength = 1.20e+06, num_iters = 1199
# training accuracy: 0.407531, validation accuracy: 0.393000
# No.61 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.20e+06, num_iters = 800
# training accuracy: 0.403776, validation accuracy: 0.399000
# No.62 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.20e+06, num_iters = 915
# training accuracy: 0.400122, validation accuracy: 0.396000
# No.63 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.20e+06, num_iters = 1048
# training accuracy: 0.403653, validation accuracy: 0.400000
# No.64 parameter combination
# learning rate = 6.92e-08, regularization strength = 1.20e+06, num_iters = 1199
# training accuracy: 0.399122, validation accuracy: 0.393000
# lr 1.000000e-08 reg 5.000000e+03 train accuracy: 0.091959 val accuracy: 0.085000
# lr 1.000000e-08 reg 1.880302e+04 train accuracy: 0.098367 val accuracy: 0.117000
# lr 1.000000e-08 reg 7.071068e+04 train accuracy: 0.389184 val accuracy: 0.381000
# lr 1.000000e-08 reg 2.659148e+05 train accuracy: 0.412633 val accuracy: 0.412000
# lr 1.000000e-08 reg 1.000000e+06 train accuracy: 0.415082 val accuracy: 0.421000
# lr 2.402249e-08 reg 5.000000e+03 train accuracy: 0.127286 val accuracy: 0.112000
# lr 2.402249e-08 reg 1.880302e+04 train accuracy: 0.310918 val accuracy: 0.326000
# lr 2.402249e-08 reg 7.071068e+04 train accuracy: 0.416980 val accuracy: 0.423000
# lr 2.402249e-08 reg 2.659148e+05 train accuracy: 0.412531 val accuracy: 0.402000
# lr 2.402249e-08 reg 1.000000e+06 train accuracy: 0.418061 val accuracy: 0.427000
# lr 4.616640e-08 reg 8.000000e+05 train accuracy: 0.405265 val accuracy: 0.402000
# lr 4.616640e-08 reg 9.157714e+05 train accuracy: 0.408776 val accuracy: 0.414000
# lr 4.616640e-08 reg 1.048297e+06 train accuracy: 0.412204 val accuracy: 0.408000
# lr 4.616640e-08 reg 1.200000e+06 train accuracy: 0.398306 val accuracy: 0.389000
# lr 5.284733e-08 reg 8.000000e+05 train accuracy: 0.417061 val accuracy: 0.415000
# lr 5.284733e-08 reg 9.157714e+05 train accuracy: 0.411000 val accuracy: 0.416000
# lr 5.284733e-08 reg 1.048297e+06 train accuracy: 0.408551 val accuracy: 0.426000
# lr 5.284733e-08 reg 1.200000e+06 train accuracy: 0.394714 val accuracy: 0.390000
# lr 5.770800e-08 reg 5.000000e+03 train accuracy: 0.256653 val accuracy: 0.247000
# lr 5.770800e-08 reg 1.880302e+04 train accuracy: 0.415571 val accuracy: 0.416000
# lr 5.770800e-08 reg 7.071068e+04 train accuracy: 0.413122 val accuracy: 0.416000
# lr 5.770800e-08 reg 2.659148e+05 train accuracy: 0.411571 val accuracy: 0.403000
# lr 5.770800e-08 reg 1.000000e+06 train accuracy: 0.385980 val accuracy: 0.409000
# lr 6.049509e-08 reg 8.000000e+05 train accuracy: 0.397714 val accuracy: 0.384000
# lr 6.049509e-08 reg 9.157714e+05 train accuracy: 0.409551 val accuracy: 0.409000
# lr 6.049509e-08 reg 1.048297e+06 train accuracy: 0.403551 val accuracy: 0.402000
# lr 6.049509e-08 reg 1.200000e+06 train accuracy: 0.407531 val accuracy: 0.393000
# lr 6.924960e-08 reg 8.000000e+05 train accuracy: 0.392265 val accuracy: 0.366000
# lr 6.924960e-08 reg 9.157714e+05 train accuracy: 0.399837 val accuracy: 0.406000
# lr 6.924960e-08 reg 1.048297e+06 train accuracy: 0.400163 val accuracy: 0.400000
# lr 6.924960e-08 reg 1.200000e+06 train accuracy: 0.399122 val accuracy: 0.393000
# lr 1.386290e-07 reg 5.000000e+03 train accuracy: 0.414020 val accuracy: 0.415000
# lr 1.386290e-07 reg 1.880302e+04 train accuracy: 0.414408 val accuracy: 0.417000
# lr 1.386290e-07 reg 7.071068e+04 train accuracy: 0.415143 val accuracy: 0.410000
# lr 1.386290e-07 reg 2.659148e+05 train accuracy: 0.413041 val accuracy: 0.407000
# lr 1.386290e-07 reg 1.000000e+06 train accuracy: 0.382224 val accuracy: 0.393000
# lr 3.330213e-07 reg 5.000000e+03 train accuracy: 0.413571 val accuracy: 0.412000
# lr 3.330213e-07 reg 1.880302e+04 train accuracy: 0.410388 val accuracy: 0.411000
# lr 3.330213e-07 reg 7.071068e+04 train accuracy: 0.415449 val accuracy: 0.416000
# lr 3.330213e-07 reg 2.659148e+05 train accuracy: 0.391000 val accuracy: 0.365000
# lr 3.330213e-07 reg 1.000000e+06 train accuracy: 0.365959 val accuracy: 0.371000
# lr 8.000000e-07 reg 5.000000e+03 train accuracy: 0.414306 val accuracy: 0.417000
# lr 8.000000e-07 reg 1.880302e+04 train accuracy: 0.416755 val accuracy: 0.420000
# lr 8.000000e-07 reg 7.071068e+04 train accuracy: 0.405837 val accuracy: 0.419000
# lr 8.000000e-07 reg 2.659148e+05 train accuracy: 0.389327 val accuracy: 0.387000
# lr 8.000000e-07 reg 1.000000e+06 train accuracy: 0.246633 val accuracy: 0.212000
# best validation accuracy achieved during cross-validation: 0.435000

# %%
# Evaluate your trained SVM on the test set
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.417

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
from cs231n.classifiers.neural_net import TwoLayerNet

input_dim = X_train_feats.shape[1]
hidden_dim = 100
num_classes = 10

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# Your code
from time import time
results = {}
best_val = -1
best_net = None
best_state = None

hidden_sizes = [500,500]
learning_rates = [5e-2, 5e-1]
num_iters = [1000, 7000]
regs = [5e-4, 3e-3]

num_classes = 10
input_size = input_dim

def acc_eval(X_train, y_train, X_val, y_val, model, verbose=False):
    y_train_pred = model.predict(X_train)
    acc_train = np.mean(y_train == y_train_pred)
    y_val_pred = model.predict(X_val)
    acc_val = np.mean(y_val == y_val_pred)
    if verbose:
        print('training accuracy: %f, validation accuracy: %f' % (acc_train, acc_val ))
    return acc_train, acc_val

def generatemesh(intervals_list, nxs_list, splitx_list):
    # x represents learning_rate, y represents regularization strength
    
    axis_list = []
    for i,inter in enumerate(intervals_list):
        if splitx_list[i] == 'line':
            locals()['x' + str(int(i))] = np.linspace(inter[0], inter[1], num=nxs_list[i])
        elif splitx_list[i] == 'log':
            locals()['x' + str(int(i))] = np.logspace(np.log10(inter[0]), np.log10(inter[1]), num=nxs_list[i])
        else:
            assert splitx_list[i] == 'line' or 'log' 'split mode should be "line" or "log"'
        axis_list.append(locals()['x' + str(int(i))])
    
    grids_list = np.meshgrid(*axis_list)
    for i, grid in enumerate(grids_list):
        grids_list[i] = grids_list[i].ravel()
    points = list(zip(*grids_list))
    return points

intervals_list = [hidden_sizes, learning_rates, num_iters, regs]; nxs_list = [1, 5, 5, 1]; splitx_list=['line', 'log', 'log', 'line']
points = generatemesh(intervals_list, nxs_list, splitx_list)

print('Roughly search')
for i,xy in enumerate(points):
    t1 = time()
    hs = int(xy[0]); lr = xy[1]; ni = int(xy[2]); reg = xy[3]
    print('# %d parameter combination' %(int(i)+1))
    print('hidden_size = %d, learning rate = %2.2e, num_iters = %d, regularization strength = %2.2e' %(hs, lr,ni, reg))
    model = TwoLayerNet(input_size, hs, num_classes)
    state = model.train(X_train_feats, y_train, X_val_feats, y_val,
                num_iters=ni, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg, keep_prob=0.5, verbose=False)
    acc_train, acc_val = acc_eval(X_train_feats, y_train, X_val_feats, y_val, model, verbose=True)
    results[(hs,lr,ni,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_net = model
        best_state = state
        best_hs = hs; best_lr = lr; best_ni = ni; best_reg = reg
    t2 = time()
    print('using time = %.3f' %(t2-t1))
# Out:
# Roughly search
# # 1 parameter combination
# hidden_size = 500, learning rate = 5.00e-02, num_iters = 1000, regularization strength = 5.00e-04
# training accuracy: 0.455204, validation accuracy: 0.436000
# using time = 3.824
# # 2 parameter combination
# hidden_size = 500, learning rate = 5.00e-02, num_iters = 1626, regularization strength = 5.00e-04
# training accuracy: 0.502286, validation accuracy: 0.489000
# using time = 5.882
# # 3 parameter combination
# hidden_size = 500, learning rate = 5.00e-02, num_iters = 2645, regularization strength = 5.00e-04
# training accuracy: 0.531122, validation accuracy: 0.517000
# using time = 9.321
# # 4 parameter combination
# hidden_size = 500, learning rate = 5.00e-02, num_iters = 4303, regularization strength = 5.00e-04
# training accuracy: 0.549224, validation accuracy: 0.535000
# using time = 15.101
# # 5 parameter combination
# hidden_size = 500, learning rate = 5.00e-02, num_iters = 7000, regularization strength = 5.00e-04
# training accuracy: 0.565388, validation accuracy: 0.539000
# using time = 24.354
# # 6 parameter combination
# hidden_size = 500, learning rate = 8.89e-02, num_iters = 1000, regularization strength = 5.00e-04
# training accuracy: 0.515143, validation accuracy: 0.505000
# using time = 3.723
# # 7 parameter combination
# hidden_size = 500, learning rate = 8.89e-02, num_iters = 1626, regularization strength = 5.00e-04
# training accuracy: 0.537959, validation accuracy: 0.521000
# using time = 5.820
# # 8 parameter combination
# hidden_size = 500, learning rate = 8.89e-02, num_iters = 2645, regularization strength = 5.00e-04
# training accuracy: 0.563918, validation accuracy: 0.532000
# using time = 9.354
# # 9 parameter combination
# hidden_size = 500, learning rate = 8.89e-02, num_iters = 4303, regularization strength = 5.00e-04
# training accuracy: 0.597673, validation accuracy: 0.576000
# using time = 15.062
# # 10 parameter combination
# hidden_size = 500, learning rate = 8.89e-02, num_iters = 7000, regularization strength = 5.00e-04
# training accuracy: 0.633102, validation accuracy: 0.592000
# using time = 24.522
# # 11 parameter combination
# hidden_size = 500, learning rate = 1.58e-01, num_iters = 1000, regularization strength = 5.00e-04
# training accuracy: 0.544490, validation accuracy: 0.526000
# using time = 3.730
# # 12 parameter combination
# hidden_size = 500, learning rate = 1.58e-01, num_iters = 1626, regularization strength = 5.00e-04
# training accuracy: 0.575510, validation accuracy: 0.545000
# using time = 5.909
# # 13 parameter combination
# hidden_size = 500, learning rate = 1.58e-01, num_iters = 2645, regularization strength = 5.00e-04
# training accuracy: 0.620898, validation accuracy: 0.587000
# using time = 9.475
# # 14 parameter combination
# hidden_size = 500, learning rate = 1.58e-01, num_iters = 4303, regularization strength = 5.00e-04
# training accuracy: 0.666980, validation accuracy: 0.597000
# using time = 15.332
# # 15 parameter combination
# hidden_size = 500, learning rate = 1.58e-01, num_iters = 7000, regularization strength = 5.00e-04
# training accuracy: 0.711571, validation accuracy: 0.609000
# using time = 24.896
# # 16 parameter combination
# hidden_size = 500, learning rate = 2.81e-01, num_iters = 1000, regularization strength = 5.00e-04
# training accuracy: 0.585898, validation accuracy: 0.554000
# using time = 3.768
# # 17 parameter combination
# hidden_size = 500, learning rate = 2.81e-01, num_iters = 1626, regularization strength = 5.00e-04
# training accuracy: 0.625429, validation accuracy: 0.579000
# using time = 6.002
# # 18 parameter combination
# hidden_size = 500, learning rate = 2.81e-01, num_iters = 2645, regularization strength = 5.00e-04
# training accuracy: 0.683469, validation accuracy: 0.599000
# using time = 9.628
# # 19 parameter combination
# hidden_size = 500, learning rate = 2.81e-01, num_iters = 4303, regularization strength = 5.00e-04
# training accuracy: 0.741551, validation accuracy: 0.595000
# using time = 15.453
# # 20 parameter combination
# hidden_size = 500, learning rate = 2.81e-01, num_iters = 7000, regularization strength = 5.00e-04
# training accuracy: 0.796612, validation accuracy: 0.601000
# using time = 24.984
# # 21 parameter combination
# hidden_size = 500, learning rate = 5.00e-01, num_iters = 1000, regularization strength = 5.00e-04
# training accuracy: 0.627980, validation accuracy: 0.578000
# using time = 3.827
# # 22 parameter combination
# hidden_size = 500, learning rate = 5.00e-01, num_iters = 1626, regularization strength = 5.00e-04
# training accuracy: 0.673510, validation accuracy: 0.561000
# using time = 6.001
# # 23 parameter combination
# hidden_size = 500, learning rate = 5.00e-01, num_iters = 2645, regularization strength = 5.00e-04
# training accuracy: 0.738755, validation accuracy: 0.594000
# using time = 9.531
# # 24 parameter combination
# hidden_size = 500, learning rate = 5.00e-01, num_iters = 4303, regularization strength = 5.00e-04
# training accuracy: 0.802592, validation accuracy: 0.603000
# using time = 15.285
# # 25 parameter combination
# hidden_size = 500, learning rate = 5.00e-01, num_iters = 7000, regularization strength = 5.00e-04
# training accuracy: 0.862633, validation accuracy: 0.580000
# using time = 24.671

# %%
hidden_sizes=[500,500]
learning_rates = [best_lr*0.8, best_lr*1.2] 
num_iters = [int(best_ni*0.8), int(best_ni*1.2)]
regs = regs
intervals_list = [hidden_sizes, learning_rates, num_iters, regs]; nxs_list = [1, 3, 3, 3]; splitx_list=['line', 'log', 'log', 'log']
points = generatemesh(intervals_list, nxs_list, splitx_list)
print('carefully search')
for i,xy in enumerate(points):
    t1 = time()
    hs = int(xy[0]); lr = xy[1]; ni = int(xy[2]); reg = xy[3]
    print('# %d parameter combination' %(int(i)+1))
    print('hidden_size = %d, learning rate = %2.2e, num_iters = %d, regularization strength = %2.2e' %(hs, lr,ni, reg))
    model = TwoLayerNet(input_size, hs, num_classes)
    state = model.train(X_train_feats, y_train, X_val_feats, y_val,
                num_iters=ni, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg, keep_prob=0.5, verbose=False)
    acc_train, acc_val = acc_eval(X_train_feats, y_train, X_val_feats, y_val, model, verbose=True)
    results[(hs,lr,ni,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_net = model
        best_state = state
        best_hs = hs; best_lr = lr; best_ni = ni; best_reg = reg
    t2 = time()
    print('using time = %.3f' %(t2-t1))


#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Print out results.
for hs,lr,ni,reg in sorted(results):
    train_accuracy, val_accuracy = results[(hs,lr,ni,reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# carefully search
# # 1 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 5599, regularization strength = 5.00e-04
# training accuracy: 0.664286, validation accuracy: 0.597000
# using time = 19.820
# # 2 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 5599, regularization strength = 7.07e-04
# training accuracy: 0.654653, validation accuracy: 0.588000
# using time = 19.769
# # 3 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 5599, regularization strength = 1.00e-03
# training accuracy: 0.647551, validation accuracy: 0.588000
# using time = 19.784
# # 4 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 6858, regularization strength = 5.00e-04
# training accuracy: 0.678347, validation accuracy: 0.602000
# using time = 24.280
# # 5 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 6858, regularization strength = 7.07e-04
# training accuracy: 0.670224, validation accuracy: 0.598000
# using time = 24.218
# # 6 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 6858, regularization strength = 1.00e-03
# training accuracy: 0.662388, validation accuracy: 0.600000
# using time = 24.199
# # 7 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 8399, regularization strength = 5.00e-04
# training accuracy: 0.692122, validation accuracy: 0.611000
# using time = 29.634
# # 8 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 8399, regularization strength = 7.07e-04
# training accuracy: 0.682327, validation accuracy: 0.614000
# using time = 29.629
# # 9 parameter combination
# hidden_size = 500, learning rate = 1.26e-01, num_iters = 8399, regularization strength = 1.00e-03
# training accuracy: 0.670020, validation accuracy: 0.601000
# using time = 29.505
# # 10 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 5599, regularization strength = 5.00e-04
# training accuracy: 0.690429, validation accuracy: 0.598000
# using time = 19.894
# # 11 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 5599, regularization strength = 7.07e-04
# training accuracy: 0.682735, validation accuracy: 0.605000
# using time = 19.833
# # 12 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 5599, regularization strength = 1.00e-03
# training accuracy: 0.672755, validation accuracy: 0.606000
# using time = 19.816
# # 13 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 6858, regularization strength = 5.00e-04
# training accuracy: 0.706204, validation accuracy: 0.606000
# using time = 24.244
# # 14 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 6858, regularization strength = 7.07e-04
# training accuracy: 0.697878, validation accuracy: 0.606000
# using time = 24.232
# # 15 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 6858, regularization strength = 1.00e-03
# training accuracy: 0.687143, validation accuracy: 0.609000
# using time = 24.232
# # 16 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 8399, regularization strength = 5.00e-04
# training accuracy: 0.721367, validation accuracy: 0.600000
# using time = 29.719
# # 17 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 8399, regularization strength = 7.07e-04
# training accuracy: 0.714408, validation accuracy: 0.624000
# using time = 29.672
# # 18 parameter combination
# hidden_size = 500, learning rate = 1.55e-01, num_iters = 8399, regularization strength = 1.00e-03
# training accuracy: 0.698531, validation accuracy: 0.608000
# using time = 29.727
# # 19 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 5599, regularization strength = 5.00e-04
# training accuracy: 0.719776, validation accuracy: 0.600000
# using time = 19.928
# # 20 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 5599, regularization strength = 7.07e-04
# training accuracy: 0.708388, validation accuracy: 0.606000
# using time = 19.921
# # 21 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 5599, regularization strength = 1.00e-03
# training accuracy: 0.694265, validation accuracy: 0.608000
# using time = 19.874
# # 22 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 6858, regularization strength = 5.00e-04
# training accuracy: 0.738796, validation accuracy: 0.594000
# using time = 24.400
# # 23 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 6858, regularization strength = 7.07e-04
# training accuracy: 0.722367, validation accuracy: 0.611000
# using time = 24.370
# # 24 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 6858, regularization strength = 1.00e-03
# training accuracy: 0.709837, validation accuracy: 0.600000
# using time = 24.330
# # 25 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 8399, regularization strength = 5.00e-04
# training accuracy: 0.753592, validation accuracy: 0.592000
# using time = 29.781
# # 26 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 8399, regularization strength = 7.07e-04
# training accuracy: 0.737735, validation accuracy: 0.622000
# using time = 29.809
# # 27 parameter combination
# hidden_size = 500, learning rate = 1.90e-01, num_iters = 8399, regularization strength = 1.00e-03
# training accuracy: 0.722857, validation accuracy: 0.621000
# using time = 29.813
# lr 5.000000e-02 reg 5.000000e-04 train accuracy: 0.455204 val accuracy: 0.436000
# lr 5.000000e-02 reg 5.000000e-04 train accuracy: 0.502286 val accuracy: 0.489000
# lr 5.000000e-02 reg 5.000000e-04 train accuracy: 0.531122 val accuracy: 0.517000
# lr 5.000000e-02 reg 5.000000e-04 train accuracy: 0.549224 val accuracy: 0.535000
# lr 5.000000e-02 reg 5.000000e-04 train accuracy: 0.565388 val accuracy: 0.539000
# lr 8.891397e-02 reg 5.000000e-04 train accuracy: 0.515143 val accuracy: 0.505000
# lr 8.891397e-02 reg 5.000000e-04 train accuracy: 0.537959 val accuracy: 0.521000
# lr 8.891397e-02 reg 5.000000e-04 train accuracy: 0.563918 val accuracy: 0.532000
# lr 8.891397e-02 reg 5.000000e-04 train accuracy: 0.597673 val accuracy: 0.576000
# lr 8.891397e-02 reg 5.000000e-04 train accuracy: 0.633102 val accuracy: 0.592000
# lr 1.264911e-01 reg 5.000000e-04 train accuracy: 0.664286 val accuracy: 0.597000
# lr 1.264911e-01 reg 7.071068e-04 train accuracy: 0.654653 val accuracy: 0.588000
# lr 1.264911e-01 reg 1.000000e-03 train accuracy: 0.647551 val accuracy: 0.588000
# lr 1.264911e-01 reg 5.000000e-04 train accuracy: 0.678347 val accuracy: 0.602000
# lr 1.264911e-01 reg 7.071068e-04 train accuracy: 0.670224 val accuracy: 0.598000
# lr 1.264911e-01 reg 1.000000e-03 train accuracy: 0.662388 val accuracy: 0.600000
# lr 1.264911e-01 reg 5.000000e-04 train accuracy: 0.692122 val accuracy: 0.611000
# lr 1.264911e-01 reg 7.071068e-04 train accuracy: 0.682327 val accuracy: 0.614000
# lr 1.264911e-01 reg 1.000000e-03 train accuracy: 0.670020 val accuracy: 0.601000
# lr 1.549193e-01 reg 5.000000e-04 train accuracy: 0.690429 val accuracy: 0.598000
# lr 1.549193e-01 reg 7.071068e-04 train accuracy: 0.682735 val accuracy: 0.605000
# lr 1.549193e-01 reg 1.000000e-03 train accuracy: 0.672755 val accuracy: 0.606000
# lr 1.549193e-01 reg 5.000000e-04 train accuracy: 0.706204 val accuracy: 0.606000
# lr 1.549193e-01 reg 7.071068e-04 train accuracy: 0.697878 val accuracy: 0.606000
# lr 1.549193e-01 reg 1.000000e-03 train accuracy: 0.687143 val accuracy: 0.609000
# lr 1.549193e-01 reg 5.000000e-04 train accuracy: 0.721367 val accuracy: 0.600000
# lr 1.549193e-01 reg 7.071068e-04 train accuracy: 0.714408 val accuracy: 0.624000
# lr 1.549193e-01 reg 1.000000e-03 train accuracy: 0.698531 val accuracy: 0.608000
# lr 1.581139e-01 reg 5.000000e-04 train accuracy: 0.544490 val accuracy: 0.526000
# lr 1.581139e-01 reg 5.000000e-04 train accuracy: 0.575510 val accuracy: 0.545000
# lr 1.581139e-01 reg 5.000000e-04 train accuracy: 0.620898 val accuracy: 0.587000
# lr 1.581139e-01 reg 5.000000e-04 train accuracy: 0.666980 val accuracy: 0.597000
# lr 1.581139e-01 reg 5.000000e-04 train accuracy: 0.711571 val accuracy: 0.609000
# lr 1.897367e-01 reg 5.000000e-04 train accuracy: 0.719776 val accuracy: 0.600000
# lr 1.897367e-01 reg 7.071068e-04 train accuracy: 0.708388 val accuracy: 0.606000
# lr 1.897367e-01 reg 1.000000e-03 train accuracy: 0.694265 val accuracy: 0.608000
# lr 1.897367e-01 reg 5.000000e-04 train accuracy: 0.738796 val accuracy: 0.594000
# lr 1.897367e-01 reg 7.071068e-04 train accuracy: 0.722367 val accuracy: 0.611000
# lr 1.897367e-01 reg 1.000000e-03 train accuracy: 0.709837 val accuracy: 0.600000
# lr 1.897367e-01 reg 5.000000e-04 train accuracy: 0.753592 val accuracy: 0.592000
# lr 1.897367e-01 reg 7.071068e-04 train accuracy: 0.737735 val accuracy: 0.622000
# lr 1.897367e-01 reg 1.000000e-03 train accuracy: 0.722857 val accuracy: 0.621000
# lr 2.811707e-01 reg 5.000000e-04 train accuracy: 0.585898 val accuracy: 0.554000
# lr 2.811707e-01 reg 5.000000e-04 train accuracy: 0.625429 val accuracy: 0.579000
# lr 2.811707e-01 reg 5.000000e-04 train accuracy: 0.683469 val accuracy: 0.599000
# lr 2.811707e-01 reg 5.000000e-04 train accuracy: 0.741551 val accuracy: 0.595000
# lr 2.811707e-01 reg 5.000000e-04 train accuracy: 0.796612 val accuracy: 0.601000
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.627980 val accuracy: 0.578000
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.673510 val accuracy: 0.561000
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.738755 val accuracy: 0.594000
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.802592 val accuracy: 0.603000
# lr 5.000000e-01 reg 5.000000e-04 train accuracy: 0.862633 val accuracy: 0.580000
# best validation accuracy achieved during cross-validation: 0.624000

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(best_state['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(best_state['train_acc_history'], label='train')
plt.plot(best_state['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.

test_acc = (best_net.predict(X_test_feats) == y_test).mean()
print(test_acc)
# Out:
# 0.592
