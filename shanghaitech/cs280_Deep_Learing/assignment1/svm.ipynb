# %% [markdown]
# # Multiclass Support Vector Machine exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# In this exercise you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
# Run some setup code for this notebook.

import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# This is a bit of magic to make matplotlib figures appear inline in the
# notebook rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12.0, 9.6) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## CIFAR-10 Data Loading and Preprocessing

# %%
# Load the raw CIFAR-10 data.
cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Clear previously loaded data.
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
# Split the data into train, val, and test sets. In addition we will
# create a small development set as a subset of the training data;
# we can use this for development so our code runs faster.
num_training = 49000
num_validation = 1000
num_test = 1000
num_dev = 500

# Our validation set will be num_validation points from the original
# training set.
mask = range(num_training, num_training + num_validation)
X_val = X_train[mask]
y_val = y_train[mask]

# Our training set will be the first num_train points from the original
# training set.
mask = range(num_training)
X_train = X_train[mask]
y_train = y_train[mask]

# We will also make a development set, which is a small subset of
# the training set.
mask = np.random.choice(num_training, num_dev, replace=False)
X_dev = X_train[mask]
y_dev = y_train[mask]

# We use the first num_test points of the original test set as our
# test set.
mask = range(num_test)
X_test = X_test[mask]
y_test = y_test[mask]

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 32, 32, 3)
# Test labels shape:  (1000,)

# %%
# Preprocessing: reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_val = np.reshape(X_val, (X_val.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))

# As a sanity check, print out the shapes of the data
print('Training data shape: ', X_train.shape)
print('Validation data shape: ', X_val.shape)
print('Test data shape: ', X_test.shape)
print('dev data shape: ', X_dev.shape)
# Out:
# Training data shape:  (49000, 3072)
# Validation data shape:  (1000, 3072)
# Test data shape:  (1000, 3072)
# dev data shape:  (500, 3072)

# %%
# Preprocessing: subtract the mean image
# first: compute the image mean based on the training data
mean_image = np.mean(X_train, axis=0)
print(mean_image[:10]) # print a few of the elements
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) # visualize the mean image
plt.show()
# Out:
# [130.64189796 135.98173469 132.47391837 130.05569388 135.34804082
#  131.75402041 130.96055102 136.14328571 132.47636735 131.48467347]

# %%
# second: subtract the mean image from train and test data
X_train -= mean_image
X_val -= mean_image
X_test -= mean_image
X_dev -= mean_image

# %%
# third: append the bias dimension of ones (i.e. bias trick) so that our SVM
# only has to worry about optimizing a single weight matrix W.
X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])

print(X_train.shape, X_val.shape, X_test.shape, X_dev.shape)
# Out:
# (49000, 3073) (1000, 3073) (1000, 3073) (500, 3073)

# %% [markdown]
# ## SVM Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/linear_svm.py**.
#
# As you can see, we have prefilled the function `compute_loss_naive` which uses for loops to evaluate the multiclass SVM loss function.

# %%
# Evaluate the naive implementation of the loss we provided for you:
from cs231n.classifiers.linear_svm import svm_loss_naive
import time

# generate a random SVM weight matrix of small numbers
W = np.random.randn(3073, 10) * 0.0001 

loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 9.092500

# %% [markdown]
# The `grad` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`. You will find it helpful to interleave your new code inside the existing function.
#
# To check that you have correctly implemented the gradient correctly, you can numerically estimate the gradient of the loss function and compare the numeric estimate to the gradient that you computed. We have provided code that does this for you:

# %% [markdown]
# * multiclss SVM classifier
# $$
#     s = \mathbf{x}W = (s_j), y = \arg\max_j s_j
# $$
# * The loss function of multiclss SVM classifier
# assume that $\mathbf{x}$ is an example input
#
# \begin{align*}
# 	L = \sum_{j\ne y_j}
# 		\begin{cases}
# 			0, & \text{otherwise } \\
# 			\mathbf{x}W_j - \mathbf{x}W_{y_j} + \Delta, & \text{if } \mathbf{x}W_j - \mathbf{x}W_{y_j} + \Delta > 0
# 		\end{cases}
# \end{align*}
# * The analytic gradient of loss function to W
# thus, for column $y_j$ of W ($y_j$ is the right class of the example $\mathbf{x}$) and column $j$ of W ($j\ne y_j$), there are:
# \begin{align*}
# 	\nabla_{W_{y_j}} L & = -\mathbf{x}\sum_{j\ne y_j} I(\mathbf{x}W_j - \mathbf{x}W_{y_j} + \Delta > 0)\\
# 	\nabla_{W_{j}} L & = \mathbf{x}I(\mathbf{x}W_j - \mathbf{x}W_{y_j} + \Delta > 0)
# \end{align*}

# %%
# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Compute the loss and its gradient at W.
loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should match
# almost exactly along all dimensions.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)

# do the gradient check once again with regularization turned on
# you didn't forget the regularization gradient did you?
loss, grad = svm_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: -7.771199 analytic: -7.742651, relative error: 1.840160e-03
# numerical: 20.377579 analytic: 20.377579, relative error: 2.616977e-11
# numerical: -10.518173 analytic: -10.518173, relative error: 2.582515e-11
# numerical: 8.986000 analytic: 8.986000, relative error: 6.040127e-13
# numerical: 12.917556 analytic: 12.917556, relative error: 2.238558e-11
# numerical: -21.205251 analytic: -21.205251, relative error: 1.259628e-11
# numerical: -6.314278 analytic: -6.314278, relative error: 1.570061e-11
# numerical: 21.563131 analytic: 21.563131, relative error: 2.282732e-11
# numerical: -14.862327 analytic: -14.862327, relative error: 4.109423e-12
# numerical: -29.861565 analytic: -29.861565, relative error: 1.822663e-13
# numerical: -12.390460 analytic: -12.390460, relative error: 1.566183e-11
# numerical: -25.724076 analytic: -25.724076, relative error: 7.212026e-13
# numerical: -3.767724 analytic: -3.767724, relative error: 5.624540e-11
# numerical: -7.179024 analytic: -7.179024, relative error: 3.407735e-11
# numerical: 39.379385 analytic: 39.379385, relative error: 6.108002e-12
# numerical: 21.559872 analytic: 21.559872, relative error: 2.777181e-12
# numerical: 31.187643 analytic: 31.187643, relative error: 1.261542e-11
# numerical: 8.153511 analytic: 8.153511, relative error: 2.492898e-11
# numerical: 12.615128 analytic: 12.577173, relative error: 1.506613e-03
# numerical: 14.355370 analytic: 14.355370, relative error: 2.136975e-11

# %% [markdown]
# ### Inline Question 1:
# It is possible that once in a while a dimension in the gradcheck will not match exactly. What could such a discrepancy be caused by? Is it a reason for concern? What is a simple example in one dimension where a gradient check could fail? How would change the margin affect of the frequency of this happening? *Hint: the SVM loss function is not strictly speaking differentiable*
#
# **Your Answer:** *fill this in.*

# %%
# Next implement the function svm_loss_vectorized; for now only compute the loss;
# we will implement the gradient in a moment.
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.linear_svm import svm_loss_vectorized
tic = time.time()
loss_vectorized, _ = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# The losses should match but your vectorized implementation should be much faster.
print('difference: %f' % (loss_naive - loss_vectorized))
# Out:
# Naive loss: 9.092500e+00 computed in 0.195596s
# Vectorized loss: 9.092500e+00 computed in 0.001947s
# difference: 0.000000

# %%
# Complete the implementation of svm_loss_vectorized, and compute the gradient
# of the loss function in a vectorized way.

# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a matrix, so
# we use the Frobenius norm to compare them.
difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)
# Out:
# Naive loss and gradient: computed in 0.197546s
# Vectorized loss and gradient: computed in 0.002389s
# difference: 0.000000

# %% [markdown]
# ### Stochastic Gradient Descent
#
# We now have vectorized and efficient expressions for the loss, the gradient and our gradient matches the numerical gradient. We are therefore ready to do SGD to minimize the loss.

# %%
# In the file linear_classifier.py, implement SGD in the function
# LinearClassifier.train() and then run it with the code below.
from cs231n.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
loss_hist = svm.train(X_train, y_train, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 787.298127
# iteration 100 / 1500: loss 287.055765
# iteration 200 / 1500: loss 108.184981
# iteration 300 / 1500: loss 42.745323
# iteration 400 / 1500: loss 19.325205
# iteration 500 / 1500: loss 10.625404
# iteration 600 / 1500: loss 7.278542
# iteration 700 / 1500: loss 5.593932
# iteration 800 / 1500: loss 5.578981
# iteration 900 / 1500: loss 5.500116
# iteration 1000 / 1500: loss 4.928974
# iteration 1100 / 1500: loss 5.503127
# iteration 1200 / 1500: loss 5.425949
# iteration 1300 / 1500: loss 4.712273
# iteration 1400 / 1500: loss 5.074540
# That took 2.364753s

# %%
# A useful debugging strategy is to plot the loss as a function of
# iteration number:
plt.plot(loss_hist)
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %%
# Write the LinearSVM.predict function and evaluate the performance on both the
# training and validation set
y_train_pred = svm.predict(X_train)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = svm.predict(X_val)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.368735
# validation accuracy: 0.373000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of about 0.4 on the validation set.
learning_rates = [1e-7, 8e-7]
regularization_strengths = [1e3, 5e4]

# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (training_accuracy, validation_accuracy). The accuracy is simply the fraction
# of data points that are correctly classified.
results = {}
best_val = -1   # The highest validation accuracy that we have seen so far.
best_svm = None # The LinearSVM object that achieved the highest validation rate.

################################################################################
# TODO:                                                                        #
# Write code that chooses the best hyperparameters by tuning on the validation #
# set. For each combination of hyperparameters, train a linear SVM on the      #
# training set, compute its accuracy on the training and validation sets, and  #
# store these numbers in the results dictionary. In addition, store the best   #
# validation accuracy in best_val and the LinearSVM object that achieves this  #
# accuracy in best_svm.                                                        #
#                                                                              #
# Hint: You should use a small value for num_iters as you develop your         #
# validation code so that the SVMs don't take much time to train; once you are #
# confident that your validation code works, you should rerun the validation   #
# code with a larger value for num_iters.                                      #
################################################################################
# Your code
from cs231n.classifiers import LinearSVM

def acc_eval(X_train, y_train, X_val, y_val, svm, verbose=False):
    y_train_pred = svm.predict(X_train)
    acc_train = np.mean(y_train == y_train_pred)
    y_val_pred = svm.predict(X_val)
    acc_val = np.mean(y_val == y_val_pred)
    if verbose:
        print('training accuracy: %f' % (acc_train, ))
        print('validation accuracy: %f' % (acc_val, ))
    return acc_train, acc_val

# x represents learning_rate, y represents regularization strength
nx = 4; ny = 20
x = np.linspace(learning_rates[0], learning_rates[1], num=nx)
y = np.linspace(regularization_strengths[0], regularization_strengths[1], num=ny)
xv, yv = np.meshgrid(x,y)
points = np.c_[xv.ravel(), yv.ravel()]
for xy in points:
    svm = LinearSVM()
    lr = xy[0]; reg = xy[1]
    print('learning rate = %2.2e, regularization strength = %2.2e' %(lr, reg))
    svm.train(X_train, y_train, learning_rate=lr, reg=reg,
                      num_iters=4500)
    acc_train, acc_val = acc_eval(X_train, y_train, X_val, y_val, svm, verbose=True)
    results[(lr,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_svm = svm
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# learning rate = 1.00e-07, regularization strength = 1.00e+03
# training accuracy: 0.387612
# validation accuracy: 0.396000
# learning rate = 3.33e-07, regularization strength = 1.00e+03
# training accuracy: 0.397224
# validation accuracy: 0.408000
# learning rate = 5.67e-07, regularization strength = 1.00e+03
# training accuracy: 0.389061
# validation accuracy: 0.372000
# learning rate = 8.00e-07, regularization strength = 1.00e+03
# training accuracy: 0.367633
# validation accuracy: 0.360000
# learning rate = 1.00e-07, regularization strength = 3.58e+03
# training accuracy: 0.395918
# validation accuracy: 0.390000
# learning rate = 3.33e-07, regularization strength = 3.58e+03
# training accuracy: 0.387878
# validation accuracy: 0.395000
# learning rate = 5.67e-07, regularization strength = 3.58e+03
# training accuracy: 0.366531
# validation accuracy: 0.363000
# learning rate = 8.00e-07, regularization strength = 3.58e+03
# training accuracy: 0.366653
# validation accuracy: 0.341000
# learning rate = 1.00e-07, regularization strength = 6.16e+03
# training accuracy: 0.394061
# validation accuracy: 0.392000
# learning rate = 3.33e-07, regularization strength = 6.16e+03
# training accuracy: 0.380000
# validation accuracy: 0.377000
# learning rate = 5.67e-07, regularization strength = 6.16e+03
# training accuracy: 0.330878
# validation accuracy: 0.339000
# learning rate = 8.00e-07, regularization strength = 6.16e+03
# training accuracy: 0.303980
# validation accuracy: 0.330000
# learning rate = 1.00e-07, regularization strength = 8.74e+03
# training accuracy: 0.385224
# validation accuracy: 0.398000
# learning rate = 3.33e-07, regularization strength = 8.74e+03
# training accuracy: 0.363408
# validation accuracy: 0.366000
# learning rate = 5.67e-07, regularization strength = 8.74e+03
# training accuracy: 0.363122
# validation accuracy: 0.365000
# learning rate = 8.00e-07, regularization strength = 8.74e+03
# training accuracy: 0.327061
# validation accuracy: 0.337000
# learning rate = 1.00e-07, regularization strength = 1.13e+04
# training accuracy: 0.383122
# validation accuracy: 0.393000
# learning rate = 3.33e-07, regularization strength = 1.13e+04
# training accuracy: 0.373980
# validation accuracy: 0.378000
# learning rate = 5.67e-07, regularization strength = 1.13e+04
# training accuracy: 0.357878
# validation accuracy: 0.371000
# learning rate = 8.00e-07, regularization strength = 1.13e+04
# training accuracy: 0.321020
# validation accuracy: 0.335000
# learning rate = 1.00e-07, regularization strength = 1.39e+04
# training accuracy: 0.377204
# validation accuracy: 0.391000
# learning rate = 3.33e-07, regularization strength = 1.39e+04
# training accuracy: 0.361000
# validation accuracy: 0.351000
# learning rate = 5.67e-07, regularization strength = 1.39e+04
# training accuracy: 0.352796
# validation accuracy: 0.350000
# learning rate = 8.00e-07, regularization strength = 1.39e+04
# training accuracy: 0.331204
# validation accuracy: 0.318000
# learning rate = 1.00e-07, regularization strength = 1.65e+04
# training accuracy: 0.377245
# validation accuracy: 0.383000
# learning rate = 3.33e-07, regularization strength = 1.65e+04
# training accuracy: 0.354122
# validation accuracy: 0.352000
# learning rate = 5.67e-07, regularization strength = 1.65e+04
# training accuracy: 0.300898
# validation accuracy: 0.301000
# learning rate = 8.00e-07, regularization strength = 1.65e+04
# training accuracy: 0.325653
# validation accuracy: 0.327000
# learning rate = 1.00e-07, regularization strength = 1.91e+04
# training accuracy: 0.375000
# validation accuracy: 0.380000
# learning rate = 3.33e-07, regularization strength = 1.91e+04
# training accuracy: 0.359306
# validation accuracy: 0.347000
# learning rate = 5.67e-07, regularization strength = 1.91e+04
# training accuracy: 0.332388
# validation accuracy: 0.336000
# learning rate = 8.00e-07, regularization strength = 1.91e+04
# training accuracy: 0.311429
# validation accuracy: 0.333000
# learning rate = 1.00e-07, regularization strength = 2.16e+04
# training accuracy: 0.370388
# validation accuracy: 0.378000
# learning rate = 3.33e-07, regularization strength = 2.16e+04
# training accuracy: 0.351816
# validation accuracy: 0.354000
# learning rate = 5.67e-07, regularization strength = 2.16e+04
# training accuracy: 0.357020
# validation accuracy: 0.351000
# learning rate = 8.00e-07, regularization strength = 2.16e+04
# training accuracy: 0.316918
# validation accuracy: 0.302000
# learning rate = 1.00e-07, regularization strength = 2.42e+04
# training accuracy: 0.367592
# validation accuracy: 0.371000
# learning rate = 3.33e-07, regularization strength = 2.42e+04
# training accuracy: 0.350163
# validation accuracy: 0.353000
# learning rate = 5.67e-07, regularization strength = 2.42e+04
# training accuracy: 0.323796
# validation accuracy: 0.317000
# learning rate = 8.00e-07, regularization strength = 2.42e+04
# training accuracy: 0.300898
# validation accuracy: 0.320000
# learning rate = 1.00e-07, regularization strength = 2.68e+04
# training accuracy: 0.370143
# validation accuracy: 0.387000
# learning rate = 3.33e-07, regularization strength = 2.68e+04
# training accuracy: 0.353571
# validation accuracy: 0.378000
# learning rate = 5.67e-07, regularization strength = 2.68e+04
# training accuracy: 0.311510
# validation accuracy: 0.325000
# learning rate = 8.00e-07, regularization strength = 2.68e+04
# training accuracy: 0.306429
# validation accuracy: 0.322000
# learning rate = 1.00e-07, regularization strength = 2.94e+04
# training accuracy: 0.366245
# validation accuracy: 0.376000
# learning rate = 3.33e-07, regularization strength = 2.94e+04
# training accuracy: 0.332102
# validation accuracy: 0.361000
# learning rate = 5.67e-07, regularization strength = 2.94e+04
# training accuracy: 0.340531
# validation accuracy: 0.338000
# learning rate = 8.00e-07, regularization strength = 2.94e+04
# training accuracy: 0.309898
# validation accuracy: 0.315000
# learning rate = 1.00e-07, regularization strength = 3.19e+04
# training accuracy: 0.367735
# validation accuracy: 0.373000
# learning rate = 3.33e-07, regularization strength = 3.19e+04
# training accuracy: 0.338184
# validation accuracy: 0.346000
# learning rate = 5.67e-07, regularization strength = 3.19e+04
# training accuracy: 0.311490
# validation accuracy: 0.316000
# learning rate = 8.00e-07, regularization strength = 3.19e+04
# training accuracy: 0.283327
# validation accuracy: 0.287000
# learning rate = 1.00e-07, regularization strength = 3.45e+04
# training accuracy: 0.352245
# validation accuracy: 0.368000
# learning rate = 3.33e-07, regularization strength = 3.45e+04
# training accuracy: 0.346490
# validation accuracy: 0.347000
# learning rate = 5.67e-07, regularization strength = 3.45e+04
# training accuracy: 0.322408
# validation accuracy: 0.315000
# learning rate = 8.00e-07, regularization strength = 3.45e+04
# training accuracy: 0.301429
# validation accuracy: 0.311000
# learning rate = 1.00e-07, regularization strength = 3.71e+04
# training accuracy: 0.355918
# validation accuracy: 0.372000
# learning rate = 3.33e-07, regularization strength = 3.71e+04
# training accuracy: 0.326449
# validation accuracy: 0.345000
# learning rate = 5.67e-07, regularization strength = 3.71e+04
# training accuracy: 0.321571
# validation accuracy: 0.342000
# learning rate = 8.00e-07, regularization strength = 3.71e+04
# training accuracy: 0.292102
# validation accuracy: 0.316000
# learning rate = 1.00e-07, regularization strength = 3.97e+04
# training accuracy: 0.359694
# validation accuracy: 0.362000
# learning rate = 3.33e-07, regularization strength = 3.97e+04
# training accuracy: 0.331204
# validation accuracy: 0.348000
# learning rate = 5.67e-07, regularization strength = 3.97e+04
# training accuracy: 0.315061
# validation accuracy: 0.320000
# learning rate = 8.00e-07, regularization strength = 3.97e+04
# training accuracy: 0.281755
# validation accuracy: 0.287000
# learning rate = 1.00e-07, regularization strength = 4.23e+04
# training accuracy: 0.358122
# validation accuracy: 0.369000
# learning rate = 3.33e-07, regularization strength = 4.23e+04
# training accuracy: 0.337510
# validation accuracy: 0.374000
# learning rate = 5.67e-07, regularization strength = 4.23e+04
# training accuracy: 0.311041
# validation accuracy: 0.329000
# learning rate = 8.00e-07, regularization strength = 4.23e+04
# training accuracy: 0.286898
# validation accuracy: 0.297000
# learning rate = 1.00e-07, regularization strength = 4.48e+04
# training accuracy: 0.364837
# validation accuracy: 0.364000
# learning rate = 3.33e-07, regularization strength = 4.48e+04
# training accuracy: 0.327857
# validation accuracy: 0.324000
# learning rate = 5.67e-07, regularization strength = 4.48e+04
# training accuracy: 0.313980
# validation accuracy: 0.326000
# learning rate = 8.00e-07, regularization strength = 4.48e+04
# training accuracy: 0.292265
# validation accuracy: 0.307000
# learning rate = 1.00e-07, regularization strength = 4.74e+04
# training accuracy: 0.358694
# validation accuracy: 0.368000
# learning rate = 3.33e-07, regularization strength = 4.74e+04
# training accuracy: 0.343163
# validation accuracy: 0.368000
# learning rate = 5.67e-07, regularization strength = 4.74e+04
# training accuracy: 0.295898
# validation accuracy: 0.299000
# learning rate = 8.00e-07, regularization strength = 4.74e+04
# training accuracy: 0.306510
# validation accuracy: 0.322000
# learning rate = 1.00e-07, regularization strength = 5.00e+04
# training accuracy: 0.355531
# validation accuracy: 0.371000
# learning rate = 3.33e-07, regularization strength = 5.00e+04
# training accuracy: 0.331755
# validation accuracy: 0.331000
# learning rate = 5.67e-07, regularization strength = 5.00e+04
# training accuracy: 0.321510
# validation accuracy: 0.347000
# learning rate = 8.00e-07, regularization strength = 5.00e+04
# training accuracy: 0.299592
# validation accuracy: 0.295000
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.387612 val accuracy: 0.396000
# lr 1.000000e-07 reg 3.578947e+03 train accuracy: 0.395918 val accuracy: 0.390000
# lr 1.000000e-07 reg 6.157895e+03 train accuracy: 0.394061 val accuracy: 0.392000
# lr 1.000000e-07 reg 8.736842e+03 train accuracy: 0.385224 val accuracy: 0.398000
# lr 1.000000e-07 reg 1.131579e+04 train accuracy: 0.383122 val accuracy: 0.393000
# lr 1.000000e-07 reg 1.389474e+04 train accuracy: 0.377204 val accuracy: 0.391000
# lr 1.000000e-07 reg 1.647368e+04 train accuracy: 0.377245 val accuracy: 0.383000
# lr 1.000000e-07 reg 1.905263e+04 train accuracy: 0.375000 val accuracy: 0.380000
# lr 1.000000e-07 reg 2.163158e+04 train accuracy: 0.370388 val accuracy: 0.378000
# lr 1.000000e-07 reg 2.421053e+04 train accuracy: 0.367592 val accuracy: 0.371000
# lr 1.000000e-07 reg 2.678947e+04 train accuracy: 0.370143 val accuracy: 0.387000
# lr 1.000000e-07 reg 2.936842e+04 train accuracy: 0.366245 val accuracy: 0.376000
# lr 1.000000e-07 reg 3.194737e+04 train accuracy: 0.367735 val accuracy: 0.373000
# lr 1.000000e-07 reg 3.452632e+04 train accuracy: 0.352245 val accuracy: 0.368000
# lr 1.000000e-07 reg 3.710526e+04 train accuracy: 0.355918 val accuracy: 0.372000
# lr 1.000000e-07 reg 3.968421e+04 train accuracy: 0.359694 val accuracy: 0.362000
# lr 1.000000e-07 reg 4.226316e+04 train accuracy: 0.358122 val accuracy: 0.369000
# lr 1.000000e-07 reg 4.484211e+04 train accuracy: 0.364837 val accuracy: 0.364000
# lr 1.000000e-07 reg 4.742105e+04 train accuracy: 0.358694 val accuracy: 0.368000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.355531 val accuracy: 0.371000
# lr 3.333333e-07 reg 1.000000e+03 train accuracy: 0.397224 val accuracy: 0.408000
# lr 3.333333e-07 reg 3.578947e+03 train accuracy: 0.387878 val accuracy: 0.395000
# lr 3.333333e-07 reg 6.157895e+03 train accuracy: 0.380000 val accuracy: 0.377000
# lr 3.333333e-07 reg 8.736842e+03 train accuracy: 0.363408 val accuracy: 0.366000
# lr 3.333333e-07 reg 1.131579e+04 train accuracy: 0.373980 val accuracy: 0.378000
# lr 3.333333e-07 reg 1.389474e+04 train accuracy: 0.361000 val accuracy: 0.351000
# lr 3.333333e-07 reg 1.647368e+04 train accuracy: 0.354122 val accuracy: 0.352000
# lr 3.333333e-07 reg 1.905263e+04 train accuracy: 0.359306 val accuracy: 0.347000
# lr 3.333333e-07 reg 2.163158e+04 train accuracy: 0.351816 val accuracy: 0.354000
# lr 3.333333e-07 reg 2.421053e+04 train accuracy: 0.350163 val accuracy: 0.353000
# lr 3.333333e-07 reg 2.678947e+04 train accuracy: 0.353571 val accuracy: 0.378000
# lr 3.333333e-07 reg 2.936842e+04 train accuracy: 0.332102 val accuracy: 0.361000
# lr 3.333333e-07 reg 3.194737e+04 train accuracy: 0.338184 val accuracy: 0.346000
# lr 3.333333e-07 reg 3.452632e+04 train accuracy: 0.346490 val accuracy: 0.347000
# lr 3.333333e-07 reg 3.710526e+04 train accuracy: 0.326449 val accuracy: 0.345000
# lr 3.333333e-07 reg 3.968421e+04 train accuracy: 0.331204 val accuracy: 0.348000
# lr 3.333333e-07 reg 4.226316e+04 train accuracy: 0.337510 val accuracy: 0.374000
# lr 3.333333e-07 reg 4.484211e+04 train accuracy: 0.327857 val accuracy: 0.324000
# lr 3.333333e-07 reg 4.742105e+04 train accuracy: 0.343163 val accuracy: 0.368000
# lr 3.333333e-07 reg 5.000000e+04 train accuracy: 0.331755 val accuracy: 0.331000
# lr 5.666667e-07 reg 1.000000e+03 train accuracy: 0.389061 val accuracy: 0.372000
# lr 5.666667e-07 reg 3.578947e+03 train accuracy: 0.366531 val accuracy: 0.363000
# lr 5.666667e-07 reg 6.157895e+03 train accuracy: 0.330878 val accuracy: 0.339000
# lr 5.666667e-07 reg 8.736842e+03 train accuracy: 0.363122 val accuracy: 0.365000
# lr 5.666667e-07 reg 1.131579e+04 train accuracy: 0.357878 val accuracy: 0.371000
# lr 5.666667e-07 reg 1.389474e+04 train accuracy: 0.352796 val accuracy: 0.350000
# lr 5.666667e-07 reg 1.647368e+04 train accuracy: 0.300898 val accuracy: 0.301000
# lr 5.666667e-07 reg 1.905263e+04 train accuracy: 0.332388 val accuracy: 0.336000
# lr 5.666667e-07 reg 2.163158e+04 train accuracy: 0.357020 val accuracy: 0.351000
# lr 5.666667e-07 reg 2.421053e+04 train accuracy: 0.323796 val accuracy: 0.317000
# lr 5.666667e-07 reg 2.678947e+04 train accuracy: 0.311510 val accuracy: 0.325000
# lr 5.666667e-07 reg 2.936842e+04 train accuracy: 0.340531 val accuracy: 0.338000
# lr 5.666667e-07 reg 3.194737e+04 train accuracy: 0.311490 val accuracy: 0.316000
# lr 5.666667e-07 reg 3.452632e+04 train accuracy: 0.322408 val accuracy: 0.315000
# lr 5.666667e-07 reg 3.710526e+04 train accuracy: 0.321571 val accuracy: 0.342000
# lr 5.666667e-07 reg 3.968421e+04 train accuracy: 0.315061 val accuracy: 0.320000
# lr 5.666667e-07 reg 4.226316e+04 train accuracy: 0.311041 val accuracy: 0.329000
# lr 5.666667e-07 reg 4.484211e+04 train accuracy: 0.313980 val accuracy: 0.326000
# lr 5.666667e-07 reg 4.742105e+04 train accuracy: 0.295898 val accuracy: 0.299000
# lr 5.666667e-07 reg 5.000000e+04 train accuracy: 0.321510 val accuracy: 0.347000
# lr 8.000000e-07 reg 1.000000e+03 train accuracy: 0.367633 val accuracy: 0.360000
# lr 8.000000e-07 reg 3.578947e+03 train accuracy: 0.366653 val accuracy: 0.341000
# lr 8.000000e-07 reg 6.157895e+03 train accuracy: 0.303980 val accuracy: 0.330000
# lr 8.000000e-07 reg 8.736842e+03 train accuracy: 0.327061 val accuracy: 0.337000
# lr 8.000000e-07 reg 1.131579e+04 train accuracy: 0.321020 val accuracy: 0.335000
# lr 8.000000e-07 reg 1.389474e+04 train accuracy: 0.331204 val accuracy: 0.318000
# lr 8.000000e-07 reg 1.647368e+04 train accuracy: 0.325653 val accuracy: 0.327000
# lr 8.000000e-07 reg 1.905263e+04 train accuracy: 0.311429 val accuracy: 0.333000
# lr 8.000000e-07 reg 2.163158e+04 train accuracy: 0.316918 val accuracy: 0.302000
# lr 8.000000e-07 reg 2.421053e+04 train accuracy: 0.300898 val accuracy: 0.320000
# lr 8.000000e-07 reg 2.678947e+04 train accuracy: 0.306429 val accuracy: 0.322000
# lr 8.000000e-07 reg 2.936842e+04 train accuracy: 0.309898 val accuracy: 0.315000
# lr 8.000000e-07 reg 3.194737e+04 train accuracy: 0.283327 val accuracy: 0.287000
# lr 8.000000e-07 reg 3.452632e+04 train accuracy: 0.301429 val accuracy: 0.311000
# lr 8.000000e-07 reg 3.710526e+04 train accuracy: 0.292102 val accuracy: 0.316000
# lr 8.000000e-07 reg 3.968421e+04 train accuracy: 0.281755 val accuracy: 0.287000
# lr 8.000000e-07 reg 4.226316e+04 train accuracy: 0.286898 val accuracy: 0.297000
# lr 8.000000e-07 reg 4.484211e+04 train accuracy: 0.292265 val accuracy: 0.307000
# lr 8.000000e-07 reg 4.742105e+04 train accuracy: 0.306510 val accuracy: 0.322000
# lr 8.000000e-07 reg 5.000000e+04 train accuracy: 0.299592 val accuracy: 0.295000
# best validation accuracy achieved during cross-validation: 0.408000

# %%
# Visualize the cross-validation results
import math
x_scatter = [math.log10(x[0]) for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.show()

# %%
# Evaluate the best svm on test set
y_test_pred = best_svm.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('linear SVM on raw pixels final test set accuracy: %f' % test_accuracy)
# Out:
# linear SVM on raw pixels final test set accuracy: 0.368000

# %%
# Visualize the learned weights for each class.
# Depending on your choice of learning rate and regularization strength, these may
# or may not be nice to look at.
w = best_svm.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)
w_min, w_max = np.min(w), np.max(w)
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
      
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# ### Inline question 2:
# Describe what your visualized SVM weights look like, and offer a brief explanation for why they look they way that they do.
#
# **Your answer:** *The SVM weights looks like the average template of the corresponding objects. SVM classifier do a inner product of a sample with the weight matrix and pick the largest score as the right label, thus the weight matrix should be similar the the image of the right label*
