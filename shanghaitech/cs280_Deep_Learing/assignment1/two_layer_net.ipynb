# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.
#
# * The notation and shapes of input, output and parameters of neural net:
# $$
# \begin{align*}
# 	& X:(N, D);	    \quad W1:(D, H); \quad b1:(1, H)\\
# 	& \hat{y}: (N,1);  \quad W2:(H, C); \quad  b2:(1, C)
# \end{align*}
# $$
#
# * first layer
#   shape:(N, H)
# $$
# \begin{align*}
# 	S1 & = XW1 + b1   \\
# 	H1 & = relu(S1)
# \end{align*}
# $$
# * second layer
# 	shape: (H, C)
# $$
# \begin{align*}
# 	S2 & = H1W2 + b2   \\
# 	H2 & = softmax(S2)
# \end{align*}
# $$
#
# * Loss function
# 	$$ L = CE(y, H2)$$
#
# * Derivations
# $$
# 	\begin{align*}
# 		\nabla_{S2}L & = \delta_{S2} = H2 - y \\
# 		\nabla_{H1}L & = \delta_{H1} = \delta_{S2}W_2^T = (H2-y)W_2^T\\
# 		\nabla_{W2}L & = H1^T\delta_{S2} = H1^T(H2-y) \\
# 		\nabla_{S1}L & = \delta_{S1} = \delta_{H1}\circ \frac{\partial H1}{\partial S1} = \delta_{H1}\circ I(S1>0) \\
# 		\nabla_{b1}L & = \delta_{S1}\\
# 		\nabla_{W1}L & = X^T\delta_{S1}
# 	\end{align*}
# $$

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.6802720496109664e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7985612998927536e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.555470e-09
# W2 max relative error: 3.440708e-09
# b2 max relative error: 3.865091e-11

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01403762529363724

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302973
# iteration 100 / 1000: loss 2.302663
# iteration 200 / 1000: loss 2.298229
# iteration 300 / 1000: loss 2.279889
# iteration 400 / 1000: loss 2.189998
# iteration 500 / 1000: loss 2.105218
# iteration 600 / 1000: loss 2.075722
# iteration 700 / 1000: loss 1.986220
# iteration 800 / 1000: loss 2.017213
# iteration 900 / 1000: loss 1.933541
# Validation accuracy:  0.28

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
# Your code
from time import time
results = {}
best_val = -1
best_net = None
best_state = None

hidden_sizes = [80,256]
learning_rates = [3e-4, 1e-3]
num_iters = [2000, 6000]
regs = [5e-2, 1]

num_classes = 10
input_size = 32 * 32 * 3

def acc_eval(X_train, y_train, X_val, y_val, model, verbose=False):
    y_train_pred = model.predict(X_train)
    acc_train = np.mean(y_train == y_train_pred)
    y_val_pred = model.predict(X_val)
    acc_val = np.mean(y_val == y_val_pred)
    if verbose:
        print('training accuracy: %f, validation accuracy: %f' % (acc_train, acc_val ))
    return acc_train, acc_val

def generatemesh(intervals_list, nxs_list, splitx_list):
    # x represents learning_rate, y represents regularization strength
    
    axis_list = []
    for i,inter in enumerate(intervals_list):
        if splitx_list[i] == 'line':
            locals()['x' + str(int(i))] = np.linspace(inter[0], inter[1], num=nxs_list[i])
        elif splitx_list[i] == 'log':
            locals()['x' + str(int(i))] = np.logspace(np.log10(inter[0]), np.log10(inter[1]), num=nxs_list[i])
        else:
            assert splitx_list[i] == 'line' or 'log' 'split mode should be "line" or "log"'
        axis_list.append(locals()['x' + str(int(i))])
    
    grids_list = np.meshgrid(*axis_list)
    for i, grid in enumerate(grids_list):
        grids_list[i] = grids_list[i].ravel()
    points = list(zip(*grids_list))
    return points

intervals_list = [hidden_sizes, learning_rates, num_iters, regs]; nxs_list = [3, 5, 4, 1]; splitx_list=['line', 'log', 'line', 'log']
points = generatemesh(intervals_list, nxs_list, splitx_list)

print('Roughly search')
for i,xy in enumerate(points):
    t1 = time()
    hs = int(xy[0]); lr = xy[1]; ni = int(xy[2]); reg = xy[3]
    print('# %d parameter combination' %(int(i)+1))
    print('hidden_size = %d, learning rate = %2.2e, num_iters = %d, regularization strength = %2.2e' %(hs, lr,ni, reg))
    model = TwoLayerNet(input_size, hs, num_classes)
    state = model.train(X_train, y_train, X_val, y_val,
                num_iters=ni, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg, keep_prob=0.5, verbose=False)
    acc_train, acc_val = acc_eval(X_train, y_train, X_val, y_val, model, verbose=True)
    results[(hs,lr,ni,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_net = model
        best_state = state
        best_hs = hs; best_lr = lr; best_ni = ni
    t2 = time()
    print('using time = %.3f' %(t2-t1))
# Out:
# Roughly search
# # 1 parameter combination
# hidden_size = 80, learning rate = 3.00e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.470490, validation accuracy: 0.470000
# using time = 6.400
# # 2 parameter combination
# hidden_size = 80, learning rate = 3.00e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.505551, validation accuracy: 0.481000
# using time = 10.469
# # 3 parameter combination
# hidden_size = 80, learning rate = 3.00e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.528939, validation accuracy: 0.496000
# using time = 14.637
# # 4 parameter combination
# hidden_size = 80, learning rate = 3.00e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.540041, validation accuracy: 0.493000
# using time = 19.206
# # 5 parameter combination
# hidden_size = 168, learning rate = 3.00e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.475776, validation accuracy: 0.470000
# using time = 9.099
# # 6 parameter combination
# hidden_size = 168, learning rate = 3.00e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.517510, validation accuracy: 0.488000
# using time = 15.001
# # 7 parameter combination
# hidden_size = 168, learning rate = 3.00e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.540122, validation accuracy: 0.504000
# using time = 20.971
# # 8 parameter combination
# hidden_size = 168, learning rate = 3.00e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.555612, validation accuracy: 0.507000
# using time = 26.876
# # 9 parameter combination
# hidden_size = 256, learning rate = 3.00e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.480469, validation accuracy: 0.465000
# using time = 13.215
# # 10 parameter combination
# hidden_size = 256, learning rate = 3.00e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.522592, validation accuracy: 0.482000
# using time = 21.881
# # 11 parameter combination
# hidden_size = 256, learning rate = 3.00e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.546265, validation accuracy: 0.501000
# using time = 30.375
# # 12 parameter combination
# hidden_size = 256, learning rate = 3.00e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.563980, validation accuracy: 0.523000
# using time = 38.868
# # 13 parameter combination
# hidden_size = 80, learning rate = 4.05e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.492510, validation accuracy: 0.460000
# using time = 6.260
# # 14 parameter combination
# hidden_size = 80, learning rate = 4.05e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.533122, validation accuracy: 0.508000
# using time = 10.319
# # 15 parameter combination
# hidden_size = 80, learning rate = 4.05e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.555347, validation accuracy: 0.500000
# using time = 14.391
# # 16 parameter combination
# hidden_size = 80, learning rate = 4.05e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.567388, validation accuracy: 0.514000
# using time = 18.476
# # 17 parameter combination
# hidden_size = 168, learning rate = 4.05e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.506041, validation accuracy: 0.483000
# using time = 9.084
# # 18 parameter combination
# hidden_size = 168, learning rate = 4.05e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.545796, validation accuracy: 0.512000
# using time = 15.111
# # 19 parameter combination
# hidden_size = 168, learning rate = 4.05e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.576184, validation accuracy: 0.517000
# using time = 20.905
# # 20 parameter combination
# hidden_size = 168, learning rate = 4.05e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.592245, validation accuracy: 0.518000
# using time = 26.878
# # 21 parameter combination
# hidden_size = 256, learning rate = 4.05e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.508673, validation accuracy: 0.480000
# using time = 13.125
# # 22 parameter combination
# hidden_size = 256, learning rate = 4.05e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.550408, validation accuracy: 0.515000
# using time = 21.722
# # 23 parameter combination
# hidden_size = 256, learning rate = 4.05e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.578714, validation accuracy: 0.531000
# using time = 30.539
# # 24 parameter combination
# hidden_size = 256, learning rate = 4.05e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.601796, validation accuracy: 0.518000
# using time = 39.533
# # 25 parameter combination
# hidden_size = 80, learning rate = 5.48e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.517327, validation accuracy: 0.489000
# using time = 6.172
# # 26 parameter combination
# hidden_size = 80, learning rate = 5.48e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.554816, validation accuracy: 0.507000
# using time = 10.280
# # 27 parameter combination
# hidden_size = 80, learning rate = 5.48e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.584898, validation accuracy: 0.528000
# using time = 14.348
# # 28 parameter combination
# hidden_size = 80, learning rate = 5.48e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.597592, validation accuracy: 0.528000
# using time = 18.318
# # 29 parameter combination
# hidden_size = 168, learning rate = 5.48e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.531367, validation accuracy: 0.499000
# using time = 9.045
# # 30 parameter combination
# hidden_size = 168, learning rate = 5.48e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.571224, validation accuracy: 0.526000
# using time = 14.923
# # 31 parameter combination
# hidden_size = 168, learning rate = 5.48e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.606653, validation accuracy: 0.525000
# using time = 21.042
# # 32 parameter combination
# hidden_size = 168, learning rate = 5.48e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.628653, validation accuracy: 0.555000
# using time = 27.086
# # 33 parameter combination
# hidden_size = 256, learning rate = 5.48e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.534327, validation accuracy: 0.501000
# using time = 13.355
# # 34 parameter combination
# hidden_size = 256, learning rate = 5.48e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.582571, validation accuracy: 0.540000
# using time = 21.857
# # 35 parameter combination
# hidden_size = 256, learning rate = 5.48e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.619061, validation accuracy: 0.533000
# using time = 30.647
# # 36 parameter combination
# hidden_size = 256, learning rate = 5.48e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.641490, validation accuracy: 0.536000
# using time = 39.610
# # 37 parameter combination
# hidden_size = 80, learning rate = 7.40e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.537612, validation accuracy: 0.495000
# using time = 6.250
# # 38 parameter combination
# hidden_size = 80, learning rate = 7.40e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.576980, validation accuracy: 0.537000
# using time = 10.337
# # 39 parameter combination
# hidden_size = 80, learning rate = 7.40e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.603796, validation accuracy: 0.517000
# using time = 14.412
# # 40 parameter combination
# hidden_size = 80, learning rate = 7.40e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.620184, validation accuracy: 0.540000
# using time = 18.516
# # 41 parameter combination
# hidden_size = 168, learning rate = 7.40e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.550449, validation accuracy: 0.498000
# using time = 9.103
# # 42 parameter combination
# hidden_size = 168, learning rate = 7.40e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.603469, validation accuracy: 0.521000
# using time = 15.360
# # 43 parameter combination
# hidden_size = 168, learning rate = 7.40e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.629204, validation accuracy: 0.535000
# using time = 20.990
# # 44 parameter combination
# hidden_size = 168, learning rate = 7.40e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.660755, validation accuracy: 0.542000
# using time = 27.360
# # 45 parameter combination
# hidden_size = 256, learning rate = 7.40e-04, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.558041, validation accuracy: 0.522000
# using time = 13.277
# # 46 parameter combination
# hidden_size = 256, learning rate = 7.40e-04, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.613429, validation accuracy: 0.521000
# using time = 22.044
# # 47 parameter combination
# hidden_size = 256, learning rate = 7.40e-04, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.651163, validation accuracy: 0.538000
# using time = 30.759
# # 48 parameter combination
# hidden_size = 256, learning rate = 7.40e-04, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.681000, validation accuracy: 0.545000
# using time = 39.603
# # 49 parameter combination
# hidden_size = 80, learning rate = 1.00e-03, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.550918, validation accuracy: 0.496000
# using time = 6.261
# # 50 parameter combination
# hidden_size = 80, learning rate = 1.00e-03, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.586939, validation accuracy: 0.495000
# using time = 10.387
# # 51 parameter combination
# hidden_size = 80, learning rate = 1.00e-03, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.617163, validation accuracy: 0.539000
# using time = 14.429
# # 52 parameter combination
# hidden_size = 80, learning rate = 1.00e-03, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.640306, validation accuracy: 0.523000
# using time = 18.516
# # 53 parameter combination
# hidden_size = 168, learning rate = 1.00e-03, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.570796, validation accuracy: 0.516000
# using time = 9.110
# # 54 parameter combination
# hidden_size = 168, learning rate = 1.00e-03, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.628245, validation accuracy: 0.522000
# using time = 15.326
# # 55 parameter combination
# hidden_size = 168, learning rate = 1.00e-03, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.661878, validation accuracy: 0.530000
# using time = 20.963
# # 56 parameter combination
# hidden_size = 168, learning rate = 1.00e-03, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.693592, validation accuracy: 0.544000
# using time = 27.067
# # 57 parameter combination
# hidden_size = 256, learning rate = 1.00e-03, num_iters = 2000, regularization strength = 5.00e-02
# training accuracy: 0.586041, validation accuracy: 0.520000
# using time = 13.250
# # 58 parameter combination
# hidden_size = 256, learning rate = 1.00e-03, num_iters = 3333, regularization strength = 5.00e-02
# training accuracy: 0.615408, validation accuracy: 0.507000
# using time = 21.826
# # 59 parameter combination
# hidden_size = 256, learning rate = 1.00e-03, num_iters = 4666, regularization strength = 5.00e-02
# training accuracy: 0.683143, validation accuracy: 0.550000
# using time = 30.562
# # 60 parameter combination
# hidden_size = 256, learning rate = 1.00e-03, num_iters = 6000, regularization strength = 5.00e-02
# training accuracy: 0.719082, validation accuracy: 0.546000
# using time = 39.442

# %%
hidden_sizes=[best_hs*0.9, best_hs*1.2]
learning_rates = [best_lr*0.8, best_lr*1.2] 
num_iters = [int(best_ni*0.8), int(best_ni*1.2)]
regs = regs
intervals_list = [hidden_sizes, learning_rates, num_iters, regs]; nxs_list = [2, 3, 3, 3]; splitx_list=['line', 'log', 'log', 'log']
points = generatemesh(intervals_list, nxs_list, splitx_list)
print('carefully search')
for i,xy in enumerate(points):
    t1 = time()
    hs = int(xy[0]); lr = xy[1]; ni = int(xy[2]); reg = xy[3]
    print('# %d parameter combination' %(int(i)+1))
    print('hidden_size = %d, learning rate = %2.2e, num_iters = %d, regularization strength = %2.2e' %(hs, lr,ni, reg))
    model = TwoLayerNet(input_size, hs, num_classes)
    state = model.train(X_train, y_train, X_val, y_val,
                num_iters=ni, batch_size=200,
                learning_rate=lr, learning_rate_decay=0.95,
                reg=reg, keep_prob=0.5, verbose=False)
    acc_train, acc_val = acc_eval(X_train, y_train, X_val, y_val, model, verbose=True)
    results[(hs,lr,ni,reg)] = (acc_train, acc_val)
    if best_val <= acc_val:
        best_val = acc_val
        best_net = model
        best_state = state
        best_hs = hs; best_lr = lr; best_reg = reg
    t2 = time()
    print('using time = %.3f' %(t2-t1))


#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Print out results.
for hs,lr,ni,reg in sorted(results):
    train_accuracy, val_accuracy = results[(hs,lr,ni,reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# carefully search
# # 1 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 4799, regularization strength = 5.00e-02
# training accuracy: 0.582184, validation accuracy: 0.544000
# using time = 20.938
# # 2 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 4799, regularization strength = 2.24e-01
# training accuracy: 0.567776, validation accuracy: 0.527000
# using time = 20.811
# # 3 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 4799, regularization strength = 1.00e+00
# training accuracy: 0.517286, validation accuracy: 0.485000
# using time = 20.889
# # 4 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 5878, regularization strength = 5.00e-02
# training accuracy: 0.597408, validation accuracy: 0.531000
# using time = 25.453
# # 5 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 5878, regularization strength = 2.24e-01
# training accuracy: 0.579082, validation accuracy: 0.538000
# using time = 25.487
# # 6 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 5878, regularization strength = 1.00e+00
# training accuracy: 0.521449, validation accuracy: 0.496000
# using time = 25.382
# # 7 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 7200, regularization strength = 5.00e-02
# training accuracy: 0.615061, validation accuracy: 0.538000
# using time = 31.268
# # 8 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 7200, regularization strength = 2.24e-01
# training accuracy: 0.592061, validation accuracy: 0.525000
# using time = 31.378
# # 9 parameter combination
# hidden_size = 151, learning rate = 4.38e-04, num_iters = 7200, regularization strength = 1.00e+00
# training accuracy: 0.528224, validation accuracy: 0.496000
# using time = 31.089
# # 10 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 4799, regularization strength = 5.00e-02
# training accuracy: 0.587020, validation accuracy: 0.519000
# using time = 25.671
# # 11 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 4799, regularization strength = 2.24e-01
# training accuracy: 0.574469, validation accuracy: 0.529000
# using time = 25.965
# # 12 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 4799, regularization strength = 1.00e+00
# training accuracy: 0.519388, validation accuracy: 0.499000
# using time = 25.684
# # 13 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 5878, regularization strength = 5.00e-02
# training accuracy: 0.604735, validation accuracy: 0.526000
# using time = 31.415
# # 14 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 5878, regularization strength = 2.24e-01
# training accuracy: 0.589612, validation accuracy: 0.524000
# using time = 31.384
# # 15 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 5878, regularization strength = 1.00e+00
# training accuracy: 0.522633, validation accuracy: 0.496000
# using time = 31.509
# # 16 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 7200, regularization strength = 5.00e-02
# training accuracy: 0.618000, validation accuracy: 0.541000
# using time = 39.106
# # 17 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 7200, regularization strength = 2.24e-01
# training accuracy: 0.600551, validation accuracy: 0.546000
# using time = 38.621
# # 18 parameter combination
# hidden_size = 201, learning rate = 4.38e-04, num_iters = 7200, regularization strength = 1.00e+00
# training accuracy: 0.529020, validation accuracy: 0.494000
# using time = 38.365
# # 19 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 4799, regularization strength = 5.00e-02
# training accuracy: 0.598143, validation accuracy: 0.546000
# using time = 20.800
# # 20 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 4799, regularization strength = 2.24e-01
# training accuracy: 0.583286, validation accuracy: 0.530000
# using time = 20.652
# # 21 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 4799, regularization strength = 1.00e+00
# training accuracy: 0.520816, validation accuracy: 0.496000
# using time = 20.680
# # 22 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 5878, regularization strength = 5.00e-02
# training accuracy: 0.623224, validation accuracy: 0.545000
# using time = 25.289
# # 23 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 5878, regularization strength = 2.24e-01
# training accuracy: 0.601490, validation accuracy: 0.529000
# using time = 25.265
# # 24 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 5878, regularization strength = 1.00e+00
# training accuracy: 0.529592, validation accuracy: 0.490000
# using time = 25.264
# # 25 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 7200, regularization strength = 5.00e-02
# training accuracy: 0.637592, validation accuracy: 0.541000
# using time = 31.091
# # 26 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 7200, regularization strength = 2.24e-01
# training accuracy: 0.616163, validation accuracy: 0.537000
# using time = 30.974
# # 27 parameter combination
# hidden_size = 151, learning rate = 5.37e-04, num_iters = 7200, regularization strength = 1.00e+00
# training accuracy: 0.531367, validation accuracy: 0.492000
# using time = 30.962
# # 28 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 4799, regularization strength = 5.00e-02
# training accuracy: 0.612327, validation accuracy: 0.524000
# using time = 25.805
# # 29 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 4799, regularization strength = 2.24e-01
# training accuracy: 0.593306, validation accuracy: 0.533000
# using time = 25.797
# # 30 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 4799, regularization strength = 1.00e+00
# training accuracy: 0.523551, validation accuracy: 0.492000
# using time = 25.832
# # 31 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 5878, regularization strength = 5.00e-02
# training accuracy: 0.627776, validation accuracy: 0.534000
# using time = 31.572
# # 32 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 5878, regularization strength = 2.24e-01
# training accuracy: 0.612959, validation accuracy: 0.544000
# using time = 31.340
# # 33 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 5878, regularization strength = 1.00e+00
# training accuracy: 0.532327, validation accuracy: 0.505000
# using time = 31.711
# # 34 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 7200, regularization strength = 5.00e-02
# training accuracy: 0.648184, validation accuracy: 0.539000
# using time = 38.766
# # 35 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 7200, regularization strength = 2.24e-01
# training accuracy: 0.622327, validation accuracy: 0.555000
# using time = 39.018
# # 36 parameter combination
# hidden_size = 201, learning rate = 5.37e-04, num_iters = 7200, regularization strength = 1.00e+00
# training accuracy: 0.538367, validation accuracy: 0.503000
# using time = 38.672
# # 37 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 4799, regularization strength = 5.00e-02
# training accuracy: 0.626041, validation accuracy: 0.548000
# using time = 20.625
# # 38 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 4799, regularization strength = 2.24e-01
# training accuracy: 0.604143, validation accuracy: 0.531000
# using time = 20.525
# # 39 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 4799, regularization strength = 1.00e+00
# training accuracy: 0.528245, validation accuracy: 0.497000
# using time = 20.587
# # 40 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 5878, regularization strength = 5.00e-02
# training accuracy: 0.641041, validation accuracy: 0.541000
# using time = 25.333
# # 41 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 5878, regularization strength = 2.24e-01
# training accuracy: 0.614980, validation accuracy: 0.525000
# using time = 25.535
# # 42 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 5878, regularization strength = 1.00e+00
# training accuracy: 0.536327, validation accuracy: 0.499000
# using time = 25.587
# # 43 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 7200, regularization strength = 5.00e-02
# training accuracy: 0.662898, validation accuracy: 0.540000
# using time = 31.276
# # 44 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 7200, regularization strength = 2.24e-01
# training accuracy: 0.632184, validation accuracy: 0.560000
# using time = 31.169
# # 45 parameter combination
# hidden_size = 151, learning rate = 6.57e-04, num_iters = 7200, regularization strength = 1.00e+00
# training accuracy: 0.539857, validation accuracy: 0.490000
# using time = 31.107
# # 46 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 4799, regularization strength = 5.00e-02
# training accuracy: 0.639837, validation accuracy: 0.531000
# using time = 26.162
# # 47 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 4799, regularization strength = 2.24e-01
# training accuracy: 0.607245, validation accuracy: 0.523000
# using time = 25.967
# # 48 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 4799, regularization strength = 1.00e+00
# training accuracy: 0.527551, validation accuracy: 0.505000
# using time = 25.774
# # 49 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 5878, regularization strength = 5.00e-02
# training accuracy: 0.661429, validation accuracy: 0.528000
# using time = 32.193
# # 50 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 5878, regularization strength = 2.24e-01
# training accuracy: 0.628878, validation accuracy: 0.530000
# using time = 31.534
# # 51 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 5878, regularization strength = 1.00e+00
# training accuracy: 0.536673, validation accuracy: 0.503000
# using time = 31.905
# # 52 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 7200, regularization strength = 5.00e-02
# training accuracy: 0.678531, validation accuracy: 0.549000
# using time = 39.289
# # 53 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 7200, regularization strength = 2.24e-01
# training accuracy: 0.645735, validation accuracy: 0.555000
# using time = 39.441
# # 54 parameter combination
# hidden_size = 201, learning rate = 6.57e-04, num_iters = 7200, regularization strength = 1.00e+00
# training accuracy: 0.546041, validation accuracy: 0.506000
# using time = 38.963
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.470490 val accuracy: 0.470000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.505551 val accuracy: 0.481000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.528939 val accuracy: 0.496000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.540041 val accuracy: 0.493000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.492510 val accuracy: 0.460000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.533122 val accuracy: 0.508000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.555347 val accuracy: 0.500000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.567388 val accuracy: 0.514000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.517327 val accuracy: 0.489000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.554816 val accuracy: 0.507000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.584898 val accuracy: 0.528000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.597592 val accuracy: 0.528000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.537612 val accuracy: 0.495000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.576980 val accuracy: 0.537000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.603796 val accuracy: 0.517000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.620184 val accuracy: 0.540000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.550918 val accuracy: 0.496000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.586939 val accuracy: 0.495000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.617163 val accuracy: 0.539000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.640306 val accuracy: 0.523000
# lr 4.381780e-04 reg 5.000000e-02 train accuracy: 0.582184 val accuracy: 0.544000
# lr 4.381780e-04 reg 2.236068e-01 train accuracy: 0.567776 val accuracy: 0.527000
# lr 4.381780e-04 reg 1.000000e+00 train accuracy: 0.517286 val accuracy: 0.485000
# lr 4.381780e-04 reg 5.000000e-02 train accuracy: 0.597408 val accuracy: 0.531000
# lr 4.381780e-04 reg 2.236068e-01 train accuracy: 0.579082 val accuracy: 0.538000
# lr 4.381780e-04 reg 1.000000e+00 train accuracy: 0.521449 val accuracy: 0.496000
# lr 4.381780e-04 reg 5.000000e-02 train accuracy: 0.615061 val accuracy: 0.538000
# lr 4.381780e-04 reg 2.236068e-01 train accuracy: 0.592061 val accuracy: 0.525000
# lr 4.381780e-04 reg 1.000000e+00 train accuracy: 0.528224 val accuracy: 0.496000
# lr 5.366563e-04 reg 5.000000e-02 train accuracy: 0.598143 val accuracy: 0.546000
# lr 5.366563e-04 reg 2.236068e-01 train accuracy: 0.583286 val accuracy: 0.530000
# lr 5.366563e-04 reg 1.000000e+00 train accuracy: 0.520816 val accuracy: 0.496000
# lr 5.366563e-04 reg 5.000000e-02 train accuracy: 0.623224 val accuracy: 0.545000
# lr 5.366563e-04 reg 2.236068e-01 train accuracy: 0.601490 val accuracy: 0.529000
# lr 5.366563e-04 reg 1.000000e+00 train accuracy: 0.529592 val accuracy: 0.490000
# lr 5.366563e-04 reg 5.000000e-02 train accuracy: 0.637592 val accuracy: 0.541000
# lr 5.366563e-04 reg 2.236068e-01 train accuracy: 0.616163 val accuracy: 0.537000
# lr 5.366563e-04 reg 1.000000e+00 train accuracy: 0.531367 val accuracy: 0.492000
# lr 6.572671e-04 reg 5.000000e-02 train accuracy: 0.626041 val accuracy: 0.548000
# lr 6.572671e-04 reg 2.236068e-01 train accuracy: 0.604143 val accuracy: 0.531000
# lr 6.572671e-04 reg 1.000000e+00 train accuracy: 0.528245 val accuracy: 0.497000
# lr 6.572671e-04 reg 5.000000e-02 train accuracy: 0.641041 val accuracy: 0.541000
# lr 6.572671e-04 reg 2.236068e-01 train accuracy: 0.614980 val accuracy: 0.525000
# lr 6.572671e-04 reg 1.000000e+00 train accuracy: 0.536327 val accuracy: 0.499000
# lr 6.572671e-04 reg 5.000000e-02 train accuracy: 0.662898 val accuracy: 0.540000
# lr 6.572671e-04 reg 2.236068e-01 train accuracy: 0.632184 val accuracy: 0.560000
# lr 6.572671e-04 reg 1.000000e+00 train accuracy: 0.539857 val accuracy: 0.490000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.475776 val accuracy: 0.470000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.517510 val accuracy: 0.488000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.540122 val accuracy: 0.504000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.555612 val accuracy: 0.507000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.506041 val accuracy: 0.483000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.545796 val accuracy: 0.512000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.576184 val accuracy: 0.517000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.592245 val accuracy: 0.518000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.531367 val accuracy: 0.499000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.571224 val accuracy: 0.526000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.606653 val accuracy: 0.525000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.628653 val accuracy: 0.555000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.550449 val accuracy: 0.498000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.603469 val accuracy: 0.521000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.629204 val accuracy: 0.535000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.660755 val accuracy: 0.542000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.570796 val accuracy: 0.516000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.628245 val accuracy: 0.522000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.661878 val accuracy: 0.530000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.693592 val accuracy: 0.544000
# lr 4.381780e-04 reg 5.000000e-02 train accuracy: 0.587020 val accuracy: 0.519000
# lr 4.381780e-04 reg 2.236068e-01 train accuracy: 0.574469 val accuracy: 0.529000
# lr 4.381780e-04 reg 1.000000e+00 train accuracy: 0.519388 val accuracy: 0.499000
# lr 4.381780e-04 reg 5.000000e-02 train accuracy: 0.604735 val accuracy: 0.526000
# lr 4.381780e-04 reg 2.236068e-01 train accuracy: 0.589612 val accuracy: 0.524000
# lr 4.381780e-04 reg 1.000000e+00 train accuracy: 0.522633 val accuracy: 0.496000
# lr 4.381780e-04 reg 5.000000e-02 train accuracy: 0.618000 val accuracy: 0.541000
# lr 4.381780e-04 reg 2.236068e-01 train accuracy: 0.600551 val accuracy: 0.546000
# lr 4.381780e-04 reg 1.000000e+00 train accuracy: 0.529020 val accuracy: 0.494000
# lr 5.366563e-04 reg 5.000000e-02 train accuracy: 0.612327 val accuracy: 0.524000
# lr 5.366563e-04 reg 2.236068e-01 train accuracy: 0.593306 val accuracy: 0.533000
# lr 5.366563e-04 reg 1.000000e+00 train accuracy: 0.523551 val accuracy: 0.492000
# lr 5.366563e-04 reg 5.000000e-02 train accuracy: 0.627776 val accuracy: 0.534000
# lr 5.366563e-04 reg 2.236068e-01 train accuracy: 0.612959 val accuracy: 0.544000
# lr 5.366563e-04 reg 1.000000e+00 train accuracy: 0.532327 val accuracy: 0.505000
# lr 5.366563e-04 reg 5.000000e-02 train accuracy: 0.648184 val accuracy: 0.539000
# lr 5.366563e-04 reg 2.236068e-01 train accuracy: 0.622327 val accuracy: 0.555000
# lr 5.366563e-04 reg 1.000000e+00 train accuracy: 0.538367 val accuracy: 0.503000
# lr 6.572671e-04 reg 5.000000e-02 train accuracy: 0.639837 val accuracy: 0.531000
# lr 6.572671e-04 reg 2.236068e-01 train accuracy: 0.607245 val accuracy: 0.523000
# lr 6.572671e-04 reg 1.000000e+00 train accuracy: 0.527551 val accuracy: 0.505000
# lr 6.572671e-04 reg 5.000000e-02 train accuracy: 0.661429 val accuracy: 0.528000
# lr 6.572671e-04 reg 2.236068e-01 train accuracy: 0.628878 val accuracy: 0.530000
# lr 6.572671e-04 reg 1.000000e+00 train accuracy: 0.536673 val accuracy: 0.503000
# lr 6.572671e-04 reg 5.000000e-02 train accuracy: 0.678531 val accuracy: 0.549000
# lr 6.572671e-04 reg 2.236068e-01 train accuracy: 0.645735 val accuracy: 0.555000
# lr 6.572671e-04 reg 1.000000e+00 train accuracy: 0.546041 val accuracy: 0.506000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.480469 val accuracy: 0.465000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.522592 val accuracy: 0.482000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.546265 val accuracy: 0.501000
# lr 3.000000e-04 reg 5.000000e-02 train accuracy: 0.563980 val accuracy: 0.523000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.508673 val accuracy: 0.480000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.550408 val accuracy: 0.515000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.578714 val accuracy: 0.531000
# lr 4.053600e-04 reg 5.000000e-02 train accuracy: 0.601796 val accuracy: 0.518000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.534327 val accuracy: 0.501000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.582571 val accuracy: 0.540000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.619061 val accuracy: 0.533000
# lr 5.477226e-04 reg 5.000000e-02 train accuracy: 0.641490 val accuracy: 0.536000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.558041 val accuracy: 0.522000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.613429 val accuracy: 0.521000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.651163 val accuracy: 0.538000
# lr 7.400828e-04 reg 5.000000e-02 train accuracy: 0.681000 val accuracy: 0.545000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.586041 val accuracy: 0.520000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.615408 val accuracy: 0.507000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.683143 val accuracy: 0.550000
# lr 1.000000e-03 reg 5.000000e-02 train accuracy: 0.719082 val accuracy: 0.546000
# best validation accuracy achieved during cross-validation: 0.560000

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(best_state['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(best_state['train_acc_history'], label='train')
plt.plot(best_state['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.522

# %% [markdown]
# **Inline Question**
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# *Your answer*: 1, 3
#
# *Your explanation:* The gap between testing accuracy and training accuracy is because of the overfitting
